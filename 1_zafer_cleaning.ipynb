# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import re
sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)

import matplotlib
print('matplotlib version: {}'.format(matplotlib.__version__))

import seaborn
print('seaborn version: {}'.format(seaborn.__version__))


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (6, 3)
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
# Out:
# matplotlib version: 3.10.1
# seaborn version: 0.13.2

# %%
#ri0=pd.read_json("as24_cars.json", lines=False)
#ri=ri0.copy()

# %%
path ='as24_cars.json'
#ri = pd.read_csv(path)  #,encoding='latin-1')
ri0=pd.read_json(path,lines=False)

# %%
ri=ri0.copy()

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   make_model                28630 non-null  object
#  1   short_description         28630 non-null  object
#  2   make                      28630 non-null  object
#  3   model                     28630 non-null  object
#  4   location                  28630 non-null  object
#  5   price                     28630 non-null  object
#  6   Body type                 28630 non-null  object
#  7   Type                      28630 non-null  object
#  8   Doors                     28271 non-null  object
#  9   Country version           16889 non-null  object
#  10  Offer number              23100 non-null  object
#  11  Warranty                  15784 non-null  object
#  12  Mileage                   28629 non-null  object
#  13  First registration        28628 non-null  object
#  14  Gearbox                   28382 non-null  object
#  15  Fuel type                 26843 non-null  object
#  16  Colour                    26906 non-null  object
#  17  Paint                     14495 non-null  object
#  18  desc                      28047 non-null  object
#  19  seller                    28630 non-null  object
#  20  Seats                     25505 non-null  object
#  21  Power                     28058 non-null  object
#  22  Engine size               27227 non-null  object
#  23  Gears                     18954 non-null  object
#  24  CO₂-emissions             18594 non-null  object
#  25  Manufacturer colour       21787 non-null  object
#  26  Drivetrain                16893 non-null  object
#  27  Cylinders                 18852 non-null  object
#  28  Fuel consumption          23385 non-null  object
#  29
# Comfort & Convenience
#    25433 non-null  object
#  30
# Entertainment & Media
#    23644 non-null  object
#  31
# Safety & Security
#        25415 non-null  object
#  32
# Extras
#                   23480 non-null  object
#  33  Empty weight              17758 non-null  object
#  34  Model code                8367 non-null   object
#  35  General inspection        12254 non-null  object
#  36  Last service              2003 non-null   object
#  37  Full service history      12565 non-null  object
#  38  Non-smoker vehicle        11594 non-null  object
#  39  Emission class            17859 non-null  object
#  40  Emissions sticker         9414 non-null   object
#  41  Upholstery colour         14569 non-null  object
#  42  Upholstery                18610 non-null  object
#  43  Production date           5908 non-null   float64
#  44  Previous owner            14015 non-null  object
#  45  Other fuel types          2313 non-null   object
#  46  Power consumption         515 non-null    object
#  47  Energy efficiency class   7804 non-null   object
#  48  CO₂-efficiency            7804 non-null   object
#  49  Fuel consumption (WLTP)   100 non-null    object
#  50  CO₂-emissions (WLTP)      116 non-null    object
#  51  Available from            393 non-null    object
#  52  Taxi or rental car        422 non-null    object
#  53  Availability              301 non-null    object
#  54  Last timing belt change   572 non-null    object
#  55  Electric Range (WLTP)     16 non-null     object
#  56  Power consumption (WLTP)  16 non-null     object
#  57  Battery Ownership         7 non-null      object
# dtypes: float64(1), object(57)
# memory usage: 13.0+ MB

# %%
ri.shape
# Out:
# (29480, 58)

# %%
#ri.describe(include="O").T

# %%
ri.isnull().sum().T
# Out:
# make_model                     850
# short_description              850
# make                           850
# model                          850
# location                       850
# price                          850
# Body type                      850
# Type                           850
# Doors                         1209
# Country version              12591
# Offer number                  6380
# Warranty                     13696
# Mileage                        851
# First registration             852
# Gearbox                       1098
# Fuel type                     2637
# Colour                        2574
# Paint                        14985
# desc                          1433
# seller                         850
# Seats                         3975
# Power                         1422
# Engine size                   2253
# Gears                        10526
# CO₂-emissions                10886
# Manufacturer colour           7693
# Drivetrain                   12587
# Cylinders                    10628
# Fuel consumption              6095
# \nComfort & Convenience\n     4047
# \nEntertainment & Media\n     5836
# \nSafety & Security\n         4065
# \nExtras\n                    6000
# Empty weight                 11722
# Model code                   21113
# General inspection           17226
# Last service                 27477
# Full service history         16915
# Non-smoker vehicle           17886
# Emission class               11621
# Emissions sticker            20066
# Upholstery colour            14911
# Upholstery                   10870
# Production date              23572
# Previous owner               15465
# Other fuel types             27167
# Power consumption            28965
# Energy efficiency class      21676
# CO₂-efficiency               21676
# Fuel consumption (WLTP)      29380
# CO₂-emissions (WLTP)         29364
# Available from               29087
# Taxi or rental car           29058
# Availability                 29179
# Last timing belt change      28908
# Electric Range (WLTP)        29464
# Power consumption (WLTP)     29464
# Battery Ownership            29473
# dtype: int64

# %%
ri.dropna(how='all').isnull().sum()
# Out:
# make_model                       0
# short_description                0
# make                             0
# model                            0
# location                         0
# price                            0
# Body type                        0
# Type                             0
# Doors                          359
# Country version              11741
# Offer number                  5530
# Warranty                     12846
# Mileage                          1
# First registration               2
# Gearbox                        248
# Fuel type                     1787
# Colour                        1724
# Paint                        14135
# desc                           583
# seller                           0
# Seats                         3125
# Power                          572
# Engine size                   1403
# Gears                         9676
# CO₂-emissions                10036
# Manufacturer colour           6843
# Drivetrain                   11737
# Cylinders                     9778
# Fuel consumption              5245
# \nComfort & Convenience\n     3197
# \nEntertainment & Media\n     4986
# \nSafety & Security\n         3215
# \nExtras\n                    5150
# Empty weight                 10872
# Model code                   20263
# General inspection           16376
# Last service                 26627
# Full service history         16065
# Non-smoker vehicle           17036
# Emission class               10771
# Emissions sticker            19216
# Upholstery colour            14061
# Upholstery                   10020
# Production date              22722
# Previous owner               14615
# Other fuel types             26317
# Power consumption            28115
# Energy efficiency class      20826
# CO₂-efficiency               20826
# Fuel consumption (WLTP)      28530
# CO₂-emissions (WLTP)         28514
# Available from               28237
# Taxi or rental car           28208
# Availability                 28329
# Last timing belt change      28058
# Electric Range (WLTP)        28614
# Power consumption (WLTP)     28614
# Battery Ownership            28623
# dtype: int64

# %%
ri.dropna(how='all',inplace= True)

# %%
ri.shape
# Out:
# (28630, 58)

# %%
ri.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'Body type', 'Type', 'Doors', 'Country version', 'Offer number',
#        'Warranty', 'Mileage', 'First registration', 'Gearbox', 'Fuel type',
#        'Colour', 'Paint', 'desc', 'seller', 'Seats', 'Power', 'Engine size',
#        'Gears', 'CO₂-emissions', 'Manufacturer colour', 'Drivetrain',
#        'Cylinders', 'Fuel consumption', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nSafety & Security\n', '\nExtras\n',
#        'Empty weight', 'Model code', 'General inspection', 'Last service',
#        'Full service history', 'Non-smoker vehicle', 'Emission class',
#        'Emissions sticker', 'Upholstery colour', 'Upholstery',
#        'Production date', 'Previous owner', 'Other fuel types',
#        'Power consumption', 'Energy efficiency class', 'CO₂-efficiency',
#        'Fuel consumption (WLTP)', 'CO₂-emissions (WLTP)', 'Available from',
#        'Taxi or rental car', 'Availability', 'Last timing belt change',
#        'Electric Range (WLTP)', 'Power consumption (WLTP)',
#        'Battery Ownership'],
#       dtype='object')

# %%
ri.columns=ri.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('co₂-', 'CO2_').str.replace('&_', '').str.replace("-","_").str.replace(r'[()]', '',regex=True)

# %%
ri.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'CO2_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_convenience',
#        'entertainment_media', 'safety_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'CO2_efficiency',
#        'fuel_consumption_wltp', 'CO2_emissions_wltp', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_wltp', 'power_consumption_wltp', 'battery_ownership'],
#       dtype='object')

# %%
#Check all columns for any ;
(ri.astype(str).apply(lambda col: col.str.contains('\*', na=False))).any()
# Out:
# make_model                 False
# short_description           True
# make                       False
# model                      False
# location                   False
# price                      False
# body_type                  False
# type                       False
# doors                      False
# country_version            False
# offer_number                True
# warranty                   False
# mileage                    False
# first_registration         False
# gearbox                    False
# fuel_type                  False
# colour                     False
# paint                      False
# desc                        True
# seller                     False
# seats                      False
# power                      False
# engine_size                False
# gears                      False
# CO2_emissions              False
# manufacturer_colour         True
# drivetrain                 False
# cylinders                  False
# fuel_consumption           False
# comfort_convenience        False
# entertainment_media        False
# safety_security            False
# extras                     False
# empty_weight               False
# model_code                  True
# general_inspection         False
# last_service               False
# full_service_history       False
# non_smoker_vehicle         False
# emission_class             False
# emissions_sticker          False
# upholstery_colour          False
# upholstery                 False
# production_date            False
# previous_owner             False
# other_fuel_types           False
# power_consumption          False
# energy_efficiency_class    False
# CO2_efficiency             False
# fuel_consumption_wltp      False
# CO2_emissions_wltp         False
# available_from             False
# taxi_or_rental_car         False
# availability               False
# last_timing_belt_change    False
# electric_range_wltp        False
# power_consumption_wltp     False
# battery_ownership          False
# dtype: bool

# %%
def clean_item(x):
    x = str(x)
    x = re.sub(r'[\n\t\r]', '', x)  # Remove control characters

    # Allowed meaningful characters
    allowed = 'a-zA-Z0-9€₺$%-+./'

    # Remove unwanted chars at the start
    x = re.sub(fr'^[^{allowed}]+', '', x)

    # Remove unwanted chars at the end
    x = re.sub(fr'[^{allowed}]+$', '', x)

    return x.strip()

# %%
def clean_cell(value):
    # return missing/null values as np.nan
    if not isinstance(value, list) and pd.isna(value):
        return np.nan

    # Helper to clean each item: remove \n, \t, \r and strip
    #def clean_item(x):
    #    return re.sub(r'[\n\t\r]', ',', str(x)).str.replace(r'[()]', ' ',regex=True)strip()
        
    if isinstance(value, list):
        # Flatten nested list and clean each element
        flat = []
        for item in value:
            if isinstance(item, list):
                flat.extend(item)
            else:
                flat.append(item)
        # Clean each flattened item
        #return ';'.join(str(x).strip() for x in flat if x is not None)
        #return tuple(clean_item(x) for x in flat if x is not None)
        cleaned = [clean_item(x) for x in flat if x is not None and str(x).strip() != '']

        if len(cleaned) == 0:
            return np.nan  # Optional: treat empty result as NaN
        elif len(cleaned) == 1:
            return cleaned[0]  # Just a single string
        else:
            return tuple(cleaned)  # A tuple if multiple items
            
    # If it's just a string, clean it    
    elif isinstance(value, str):
        # Remove unwanted whitespace characters and trailing spaces
         return clean_item(value)
        
    # Leave numbers or other types unchanged 
    else:
        return value

# %%
ri1=ri.copy()

# %%
ri1 = ri1.applymap(clean_cell)
ri1.head(5)
# Out:
#                make_model         short_description           make     model  \
# 0     Mercedes-Benz A 160                       CDi  Mercedes-Benz     A 160
# 1   Mercedes-Benz EQE 350                      350+  Mercedes-Benz   EQE 350
# 2  Mercedes-Benz A 45 AMG          S 4Matic+ 8G-DCT  Mercedes-Benz  A 45 AMG
# 3  Mercedes-Benz A 35 AMG            4Matic+ 7G-DCT  Mercedes-Benz  A 35 AMG
# 4  Mercedes-Benz A 45 AMG  200CDI BE Line 4M 7G-DCT  Mercedes-Benz  A 45 AMG
#
#                                             location      price body_type  \
# 0  P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...  € 16,950.   Compact
# 1       APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES  € 80,900.   Compact
# 2  PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...  € 69,900.   Compact
# 3  Carrer de Provença, 31 Local,  8029 BARCELONA, ES  € 46,990.   Compact
# 4             CARRIL ARAGONES 4,  30007 CASILLAS, ES  € 16,800.   Compact
#
#              type doors country_version offer_number   warranty     mileage  \
# 0            Used     5           Spain      7468157  24 months  120,200 km
# 1  Pre-registered     4           Spain      7054863  24 months    5,000 km
# 2            Used     5           Spain      7410454  12 months   18,900 km
# 3            Used     5           Spain      7464503  12 months   18,995 km
# 4            Used     5           Spain      7127931  12 months  197,000 km
#
#   first_registration    gearbox fuel_type  colour     paint  \
# 0            06/2016     Manual    Diesel   Black  Metallic
# 1            06/2022  Automatic  Electric     NaN       NaN
# 2            07/2020  Automatic  Gasoline    Grey       NaN
# 3            01/2020  Automatic  Gasoline  Yellow       NaN
# 4            09/2015  Automatic    Diesel   White  Metallic
#
#                                                 desc  seller seats  \
# 0  (Precio al contado: 16950 euros, Vehículo con ...  Dealer   NaN
# 1  (Precio al contado: 88900 euros, AUTO OJA S.A....  Dealer     5
# 2  (Gris MANUFAKTUR mountaingrau magno, Linea/Est...  Dealer     5
# 3  (Precio al contado: 48990 euros, BONIFICACION ...  Dealer     5
# 4  (Precio al contado: 17400 euros, Vehículo en p...  Dealer     5
#
#              power engine_size gears   CO2_emissions manufacturer_colour  \
# 0              NaN         NaN   NaN             NaN                 NaN
# 1  215 kW (292 hp)        1 cc     9  0 g/km (comb.)     Negro Obsidiana
# 2  310 kW (421 hp)    1,991 cc     8             NaN  Mountaingrau magno
# 3  225 kW (306 hp)    1,991 cc     7             NaN        Amarillo Sol
# 4  100 kW (136 hp)    2,143 cc     7             NaN                 NaN
#
#   drivetrain cylinders                                   fuel_consumption  \
# 0        NaN       NaN                                                NaN
# 1        NaN       NaN                                                NaN
# 2        4WD         4  (8.4 l/100 km (comb.), 10.9 l/100 km (city), 5...
# 3        4WD         4  (7.3 l/100 km (comb.), 9.3 l/100 km (city), 6....
# 4        4WD         4  (4.9 l/100 km (comb.), 5.7 l/100 km (city), 4....
#
#                                  comfort_convenience  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Air conditioning, Automatic climate control, P...
# 4  Air conditioning, Electrical side mirrors, Mul...
#
#               entertainment_media  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             USB
# 4  Bluetooth, CD player, MP3, USB
#
#                                      safety_security       extras  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3  ABS, Central door lock, Driver-side airbag, El...  Sport seats
# 4  ABS, Central door lock, Driver-side airbag, El...          NaN
#
#   empty_weight model_code general_inspection last_service  \
# 0          NaN        NaN                NaN          NaN
# 1          NaN        NaN                NaN          NaN
# 2          NaN        NaN                NaN          NaN
# 3          NaN        NaN                NaN          NaN
# 4     1,545 kg        NaN                NaN          NaN
#
#   full_service_history non_smoker_vehicle emission_class emissions_sticker  \
# 0                  NaN                NaN            NaN               NaN
# 1                  NaN                NaN            NaN               NaN
# 2                  NaN                NaN            NaN               NaN
# 3                  NaN                NaN            NaN               NaN
# 4                  NaN                NaN            NaN               NaN
#
#   upholstery_colour upholstery  production_date previous_owner  \
# 0               NaN        NaN              NaN            NaN
# 1               NaN        NaN              NaN            NaN
# 2               NaN        NaN              NaN            NaN
# 3               NaN        NaN              NaN            NaN
# 4               NaN        NaN              NaN            NaN
#
#   other_fuel_types power_consumption energy_efficiency_class CO2_efficiency  \
# 0              NaN               NaN                     NaN            NaN
# 1              NaN               NaN                     NaN            NaN
# 2              NaN               NaN                     NaN            NaN
# 3              NaN               NaN                     NaN            NaN
# 4              NaN               NaN                     NaN            NaN
#
#   fuel_consumption_wltp CO2_emissions_wltp available_from taxi_or_rental_car  \
# 0                   NaN                NaN            NaN                NaN
# 1                   NaN                NaN            NaN                NaN
# 2                   NaN                NaN            NaN                NaN
# 3                   NaN                NaN            NaN                NaN
# 4                   NaN                NaN            NaN                NaN
#
#   availability last_timing_belt_change electric_range_wltp  \
# 0          NaN                     NaN                 NaN
# 1          NaN                     NaN                 NaN
# 2          NaN                     NaN                 NaN
# 3          NaN                     NaN                 NaN
# 4          NaN                     NaN                 NaN
#
#   power_consumption_wltp battery_ownership
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN

# %%
# def clean_price(price):
#     try:
#         price = re.sub(r"[^\d,]", "", str(price))
#         return float(price.replace(",", "")) if price else None
#     except:
#         return None

def clean_price_column(df, column_name):
    return df[column_name] \
             .astype(str) \
             .str.replace(r"[^\d,]", "", regex=True) \
             .str.replace(",", "") \
             .astype(float)

def extract_country(location):
    try:
        parts = str(location).strip().split()
        return parts[-1] if parts else None
    except:
        return None

def clean_warranty(warranty):
    try:
        match = re.search(r'(\d+)', str(warranty))
        return int(match.group(1)) if match else None
    except:
        return None

# def clean_mileage(mileage):
#     try:
#         mileage = re.sub(r"[^\d]", "", str(mileage))
#         return int(mileage) if mileage else None
#     except:
#         return None

def clean_mileage(mileage):
    try:
        match = re.search(r"([\d.,]+)", str(mileage))
        if match:
            number = match.group(1)
            number = number.replace(",", "")  # "120,200" → "120200"
            return float(number)
        else:
            return None
    except:
        return None


def extract_horsepower(power):
    try:
        match = re.search(r'\((\d+)\s*hp\)', str(power))
        return int(match.group(1)) if match else None
    except:
        return None

def extract_engine_size(size):
    try:
        # Stringe çevir, yalnızca sayı ve virgül olan kısmı ayıkla
        match = re.search(r"([\d.,]+)", str(size))
        if match:
            # Bulunan sayı kısmını al
            number = match.group(1)
            # Virgülü kaldır ve noktaya çevirme: "1,991" → "1991"
            number = number.replace(",", "")
            return float(number)
        else:
            return None
    except:
        return None

# empty_weight sütunu
def clean_numeric_column_inplace(df, column_name):
    """
    DataFrame içindeki bir sütundaki '1,395 kg' gibi değerlerden sadece sayısal kısmı alır
    ve aynı sütunu float olarak günceller.
    """
    df[column_name] = (
        df[column_name]
          .astype(str)
          .str.extract(r'([\d.,]+)')[0]   # sadece sayıyı al
          .str.replace(",", "")           # virgülü kaldır
          .astype(float)                  # float'a çevir
    )

# # empty_weight sütunu
# def clean_weight(val):
#     if pd.isna(val):
#         return None  # NaN'ler 0 olarak döner
    
#     try:
#         # String'e çevir, "kg" çıkar, virgül sil, boşlukları temizle
#         val_str = str(val).replace('kg', '').replace(',', '').strip()
#         return int(val_str)
#     except:
#         return None
# ri1['empty_weight'] = ri1['empty_weight'].apply(clean_weight)

# %%
ri1['price'] = clean_price_column(ri1, 'price')
ri1["location"] = ri1["location"].apply(extract_country)
ri1["warranty"] = ri1["warranty"].apply(clean_warranty)
ri1["mileage"] = ri1["mileage"].apply(clean_mileage)
ri1["power"] = ri1["power"].apply(extract_horsepower)
ri1["engine_size"] = ri1["engine_size"].apply(extract_engine_size)
clean_numeric_column_inplace(ri1, 'empty_weight')

# %%
ri1[["price","location","warranty","mileage","power","engine_size","empty_weight"]].head()
# Out:
#      price location  warranty   mileage  power  engine_size  empty_weight
# 0  16950.0       ES      24.0  120200.0    NaN          NaN           NaN
# 1  80900.0       ES      24.0    5000.0  292.0          1.0           NaN
# 2  69900.0       ES      12.0   18900.0  421.0       1991.0           NaN
# 3  46990.0       ES      12.0   18995.0  306.0       1991.0           NaN
# 4  16800.0       ES      12.0  197000.0  136.0       2143.0        1545.0

# %%
# Task 3 Age
# 'First registration' sütununu datetime formatına çevir, hatalıysa NaT yap
ri1['first_registration'] = pd.to_datetime(ri1['first_registration'], errors='coerce')

# %%
ri1['age'] = 2022 - ri1['first_registration'].dt.year

# %%
ri1.head(2)
# Out:
#               make_model short_description           make    model location  \
# 0    Mercedes-Benz A 160               CDi  Mercedes-Benz    A 160       ES
# 1  Mercedes-Benz EQE 350              350+  Mercedes-Benz  EQE 350       ES
#
#      price body_type            type doors country_version offer_number  \
# 0  16950.0   Compact            Used     5           Spain      7468157
# 1  80900.0   Compact  Pre-registered     4           Spain      7054863
#
#    warranty   mileage first_registration    gearbox fuel_type colour  \
# 0      24.0  120200.0         2016-06-01     Manual    Diesel  Black
# 1      24.0    5000.0         2022-06-01  Automatic  Electric    NaN
#
#       paint                                               desc  seller seats  \
# 0  Metallic  (Precio al contado: 16950 euros, Vehículo con ...  Dealer   NaN
# 1       NaN  (Precio al contado: 88900 euros, AUTO OJA S.A....  Dealer     5
#
#    power  engine_size gears   CO2_emissions manufacturer_colour drivetrain  \
# 0    NaN          NaN   NaN             NaN                 NaN        NaN
# 1  292.0          1.0     9  0 g/km (comb.)     Negro Obsidiana        NaN
#
#   cylinders fuel_consumption comfort_convenience entertainment_media  \
# 0       NaN              NaN                 NaN                 NaN
# 1       NaN              NaN                 NaN                 NaN
#
#   safety_security extras  empty_weight model_code general_inspection  \
# 0             NaN    NaN           NaN        NaN                NaN
# 1             NaN    NaN           NaN        NaN                NaN
#
#   last_service full_service_history non_smoker_vehicle emission_class  \
# 0          NaN                  NaN                NaN            NaN
# 1          NaN                  NaN                NaN            NaN
#
#   emissions_sticker upholstery_colour upholstery  production_date  \
# 0               NaN               NaN        NaN              NaN
# 1               NaN               NaN        NaN              NaN
#
#   previous_owner other_fuel_types power_consumption energy_efficiency_class  \
# 0            NaN              NaN               NaN                     NaN
# 1            NaN              NaN               NaN                     NaN
#
#   CO2_efficiency fuel_consumption_wltp CO2_emissions_wltp available_from  \
# 0            NaN                   NaN                NaN            NaN
# 1            NaN                   NaN                NaN            NaN
#
#   taxi_or_rental_car availability last_timing_belt_change electric_range_wltp  \
# 0                NaN          NaN                     NaN                 NaN
# 1                NaN          NaN                     NaN                 NaN
#
#   power_consumption_wltp battery_ownership  age
# 0                    NaN               NaN  6.0
# 1                    NaN               NaN  0.0

# %%
ri1["previous_owner"].value_counts()
# Out:
# previous_owner
# (50 km, 06/2022, 1)           64
# (10 km, 08/2022, 1)           59
# (10 km, 07/2022, 1)           45
# (10 km, 09/2022, 1)           38
# (10 km, 05/2022, 1)           37
# (10 km, 06/2022, 1)           34
# (20 km, 08/2022, 1)           21
# (15 km, 09/2022, 1)           19
# (100 km, 09/2022, 1)          17
# (20 km, 07/2022, 1)           17
# (10 km, 03/2022, 1)           15
# (5,000 km, 05/2022, 1)        14
# (100 km, 08/2022, 1)          14
# (10 km, 01/2022, 1)           14
# (10 km, 04/2022, 1)           12
# (5 km, 07/2022, 1)            12
# (10 km, 02/2022, 1)           12
# (35 km, 08/2022, 1)           11
# (20 km, 09/2022, 1)           11
# (1,000 km, 07/2022, 1)        11
# (15 km, 08/2022, 1)           10
# (2,001 km, 09/2022, 1)        10
# (5 km, 09/2022, 1)            10
# (3,000 km, 04/2022, 1)        10
# (9,900 km, 09/2022, 1)        10
# (100 km, 07/2022, 1)          10
# (12 km, 08/2022, 1)            9
# (9,900 km, 07/2022, 1)         9
# (99 km, 07/2022, 1)            9
# (5 km, 08/2022, 1)             9
# (15 km, 03/2022, 1)            9
# (150 km, 08/2022, 1)           8
# (50 km, 10/2021, 1)            8
# (5,000 km, 09/2022, 1)         8
# (10 km, 09/2017, 1)            8
# (5,000 km, 04/2022, 1)         7
# (100 km, 04/2022, 1)           7
# (50 km, 03/2022, 1)            7
# (9,900 km, 08/2022, 1)         7
# (3,000 km, 09/2022, 1)         7
# (9 km, 08/2022, 2)             7
# (4,900 km, 05/2022, 1)         7
# (10 km, 12/2021, 1)            7
# (50 km, 08/2022, 1)            7
# (3,000 km, 08/2022, 1)         7
# (10 km, 05/2022, 2)            7
# (5,000 km, 03/2022, 1)         6
# (35,550 km, 11/2018, 1)        6
# (120,050 km, 05/2018, 1)       6
# (5 km, 06/2022, 1)             6
# (50 km, 07/2022, 1)            6
# (1,555 km, 05/2022, 1)         6
# (50 km, 05/2022, 1)            6
# (6,000 km, 04/2022, 1)         6
# (8,000 km, 08/2022, 1)         6
# (99 km, 06/2022, 1)            5
# (3,500 km, 06/2022, 1)         5
# (10,000 km, 12/2021, 1)        5
# (4,500 km, 09/2022, 1)         5
# (2,500 km, 06/2022, 1)         5
# (150 km, 09/2022, 1)           5
# (1,500 km, 09/2022, 1)         5
# (9,500 km, 05/2022, 1)         5
# (5,000 km, 06/2022, 1)         5
# (150 km, 07/2022, 1)           5
# (3,500 km, 07/2022, 1)         5
# (20 km, 04/2022, 1)            5
# (100 km, 02/2022, 1)           5
# (5,000 km, 09/2021, 1)         5
# (5,000 km, 01/2022, 1)         5
# (20 km, 06/2022, 1)            5
# (15 km, 04/2022, 1)            5
# (3,000 km, 07/2022, 1)         5
# (4,900 km, 08/2022, 1)         5
# (4,500 km, 06/2022, 1)         5
# (2,500 km, 05/2022, 1)         5
# (100 km, 06/2022, 1)           5
# (5,000 km, 07/2022, 1)         5
# (3,000 km, 06/2022, 1)         5
# (4,900 km, 09/2022, 1)         5
# (8,000 km, 02/2022, 1)         5
# (3,500 km, 04/2022, 1)         5
# (10,000 km, 07/2022, 1)        5
# (20 km, 05/2022, 1)            5
# (50 km, 09/2022, 1)            4
# (5,100 km, 08/2022, 1)         4
# (100 km, 01/2022, 1)           4
# (10 km, 11/2021, 1)            4
# (4,990 km, 05/2022, 1)         4
# (5 km, 12/2021, 1)             4
# (6,900 km, 04/2022, 1)         4
# (150 km, 05/2022, 1)           4
# (1,500 km, 08/2022, 1)         4
# (9,500 km, 12/2021, 1)         4
# (12,500 km, 10/2021, 1)        4
# (10,000 km, 06/2022, 1)        4
# (5 km, 05/2021, 1)             4
# (7,500 km, 03/2022, 1)         4
# (1,001 km, 05/2022, 1)         4
# (30,000 km, 07/2019, 1)        4
# (8,900 km, 12/2021, 1)         4
# (64,460 km, 06/2017, 1)        4
# (54,500 km, 02/2020, 1)        4
# (63,650 km, 05/2020, 1)        4
# (187,500 km, 07/2008, 2)       4
# (3,000 km, 01/2022, 1)         4
# (1,500 km, 06/2022, 1)         4
# (9,900 km, 12/2021, 1)         4
# (9,990 km, 04/2022, 1)         4
# (5,000 km, 02/2022, 1)         4
# (45 km, 08/2022, 1)            4
# (100 km, 11/2021, 1)           4
# (9,750 km, 12/2021, 1)         4
# (1,500 km, 07/2022, 1)         4
# (50 km, 04/2022, 1)            4
# (73,980 km, 06/2018, 1)        4
# (6,500 km, 03/2022, 1)         4
# (1 km, 05/2022, 1)             4
# (44,840 km, 09/2019, 1)        4
# (16,300 km, 10/2018, 1)        4
# (136,250 km, 05/2010, 3)       4
# (68,000 km, 04/2000, 1)        4
# (4,900 km, 06/2022, 1)         4
# (23,650 km, 09/2018, 1)        4
# (8,000 km, 04/2022, 1)         4
# (88,600 km, 06/2015, 2)        4
# (90,000 km, 08/2018, 1)        4
# (2,500 km, 03/2022, 1)         4
# (250 km, 09/2022, 1)           4
# (20,394 km, 09/2021, 1)        4
# (8,000 km, 09/2021, 1)         4
# (4,990 km, 06/2022, 1)         4
# (12 km, 06/2022, 1)            4
# (53,634 km, 06/2011, 1)        3
# (15 km, 06/2021, 1)            3
# (46,000 km, 03/2019, 1)        3
# (10,000 km, 05/2022, 1)        3
# (1,000 km, 06/2022, 1)         3
# (2,900 km, 04/2022, 1)         3
# (1,000 km, 08/2021, 1)         3
# (7,900 km, 12/2021, 1)         3
# (3,000 km, 09/2021, 1)         3
# (110 km, 08/2022, 1)           3
# (4,000 km, 07/2022, 1)         3
# (500 km, 07/2022, 1)           3
# (550 km, 07/2022, 1)           3
# (9,999 km, 04/2022, 1)         3
# (50 km, 12/2021, 1)            3
# (9,900 km, 06/2022, 1)         3
# (15,000 km, 08/2021, 1)        3
# (45,936 km, 05/2013, 1)        3
# (9,990 km, 05/2022, 1)         3
# (26,500 km, 09/2020, 1)        3
# (9,999 km, 12/2021, 1)         3
# (70,950 km, 05/2017, 1)        3
# (28,000 km, 01/2018, 1)        3
# (12 km, 07/2022, 1)            3
# (11,500 km, 12/2021, 1)        3
# (5,000 km, 12/2021, 1)         3
# (7,500 km, 07/2022, 1)         3
# (34,900 km, 02/2019, 2)        3
# (10 km, 06/2021, 1)            3
# (20,750 km, 07/2021, 1)        3
# (5,000 km, 08/2022, 1)         3
# (45,000 km, 02/2018, 2)        3
# (1,050 km, 08/2022, 1)         3
# (6,500 km, 02/2022, 1)         3
# (15 km, 05/2022, 1)            3
# (15 km, 07/2022, 1)            3
# (50 km, 11/2021, 1)            3
# (1 km, 07/2022, 1)             3
# (1 km, 08/2022, 1)             3
# (3,500 km, 01/2022, 1)         3
# (10,000 km, 11/2021, 1)        3
# (71,000 km, 08/2018, 1)        3
# (5 km, 03/2021, 1)             3
# (50,000 km, 07/2018, 1)        3
# (20,000 km, 03/2022, 1)        3
# (8,000 km, 01/2022, 1)         3
# (8,800 km, 12/2021, 1)         3
# (3 km, 09/2022, 1)             3
# (4,500 km, 04/2022, 1)         3
# (15 km, 06/2022, 1)            3
# (31,000 km, 06/2020, 1)        3
# (49,500 km, 06/2019, 1)        3
# (3,000 km, 02/2022, 1)         3
# (250 km, 05/2022, 1)           3
# (6,600 km, 01/2022, 1)         3
# (2,001 km, 06/2022, 1)         3
# (7 km, 07/2022, 2)             3
# (500 km, 04/2022, 1)           3
# (8,000 km, 05/2021, 1)         3
# (500 km, 09/2022, 1)           3
# (85,000 km, 08/2017, 1)        3
# (6,000 km, 09/2022, 1)         3
# (3,500 km, 09/2022, 1)         3
# (8,000 km, 07/2022, 1)         3
# (99 km, 12/2021, 1)            3
# (150 km, 06/2022, 1)           3
# (2,000 km, 04/2022, 1)         3
# (9,000 km, 10/2021, 1)         3
# (5,500 km, 09/2022, 1)         3
# (9,500 km, 04/2022, 1)         3
# (1 km, 06/2022, 1)             3
# (5,900 km, 12/2021, 1)         3
# (5,000 km, 06/2021, 1)         3
# (2,500 km, 07/2022, 1)         3
# (16,010 km, 03/2022, 1)        3
# (6,900 km, 09/2022, 1)         3
# (12,000 km, 08/2021, 1)        3
# (46,500 km, 10/2019, 1)        3
# (1,000 km, 04/2022, 1)         3
# (4,900 km, 07/2022, 1)         3
# (10 km, 04/2017, 1)            3
# (7 km, 04/2022, 2)             3
# (8,000 km, 03/2022, 1)         3
# (7,000 km, 04/2022, 1)         3
# (10 km, 10/2021, 1)            3
# (11,900 km, 12/2021, 1)        3
# (2,500 km, 12/2021, 1)         3
# (0 km, 02/2022, 1)             3
# (6,000 km, 12/2021, 1)         3
# (8,000 km, 06/2022, 1)         3
# (9,950 km, 12/2021, 1)         3
# (5 km, 11/2021, 1)             3
# (10,000 km, 09/2022, 1)        3
# (9,500 km, 08/2022, 1)         3
# (8,000 km, 12/2021, 1)         3
# (1,500 km, 05/2022, 1)         3
# (9 km, 06/2022, 1)             3
# (22,939 km, 05/2021, 1)        3
# (5,000 km, 10/2021, 2)         3
# (96,260 km, 07/2009, 2)        2
# (108,000 km, 06/2007, 3)       2
# (69,747 km, 05/2007, 1)        2
# (196,000 km, 08/2007, 1)       2
# (120,933 km, 08/2006, 6)       2
# (117,467 km, 02/2008, 4)       2
# (72,500 km, 05/2003, 2)        2
# (155,923 km, 08/2006, 2)       2
# (164,000 km, 10/2007, 2)       2
# (59,000 km, 05/2008, 1)        2
# (29,608 km, 03/2014, 1)        2
# (339,701 km, 06/1999, 6)       2
# (182,000 km, 10/2008, 2)       2
# (129,830 km, 03/2009, 1)       2
# (150,283 km, 02/2007, 4)       2
# (309,434 km, 01/2005, 7)       2
# (236,157 km, 04/2011, 3)       2
# (12,000 km, 02/2022, 1)        2
# (194,891 km, 05/2010, 2)       2
# (138,900 km, 03/2009, 3)       2
# (99,950 km, 06/2003, 2)        2
# (96,407 km, 04/2002, 9)        2
# (149,000 km, 11/2011, 1)       2
# (193,000 km, 06/2002, 1)       2
# (108,723 km, 11/2017, 2)       2
# (272,358 km, 06/2009, 2)       2
# (150,411 km, 04/2010, 1)       2
# (146,348 km, 10/2011, 1)       2
# (166,664 km, 05/2004, 1)       2
# (135,750 km, 06/2000, 2)       2
# (216,000 km, 05/2006, 2)       2
# (120,000 km, 01/2008, 1)       2
# (95,858 km, 03/2012, 2)        2
# (63,000 km, 07/2015, 3)        2
# (181,100 km, 02/2008, 2)       2
# (248,000 km, 09/2010, 1)       2
# (130,000 km, 04/2002, 1)       2
# (117,000 km, 02/2002, 3)       2
# (309,449 km, 06/2009, 3)       2
# (89,000 km, 11/2012, 2)        2
# (205,000 km, 01/2008, 2)       2
# (69,000 km, 04/2011, 2)        2
# (105,600 km, 09/2010, 1)       2
# (158,900 km, 06/2007, 6)       2
# (157,000 km, 03/2004, 2)       2
# (226,518 km, 05/2011, 2)       2
# (152,918 km, 10/2001, 4)       2
# (61,000 km, 09/2002, 1)        2
# (116,018 km, 10/2007, 1)       2
# (147,000 km, 04/2012, 2)       2
# (163,000 km, 09/2006, 2)       2
# (157,000 km, 06/2003, 2)       2
# (282,900 km, 06/2007, 5)       2
# (97,200 km, 07/2006, 1)        2
# (219,601 km, 07/2008, 1)       2
# (105,000 km, 07/2012, 1)       2
# (59,750 km, 03/2007, 2)        2
# (235,822 km, 06/1999, 2)       2
# (117,800 km, 05/2001, 2)       2
# (312,332 km, 04/2004, 3)       2
# (261,873 km, 11/2009, 4)       2
# (91,000 km, 02/2005, 4)        2
# (130,891 km, 09/2007, 2)       2
# (251,386 km, 03/2007, 2)       2
# (151,044 km, 05/2010, 2)       2
# (253,800 km, 04/2009, 2)       2
# (273,458 km, 03/2011, 2)       2
# (100,000 km, 06/2010, 1)       2
# (191,000 km, 02/2008, 3)       2
# (143,000 km, 07/2001, 2)       2
# (299,911 km, 03/2007, 2)       2
# (266,147 km, 04/2009, 5)       2
# (198,000 km, 07/2007, 1)       2
# (7,500 km, 04/2022, 1)         2
# (153,500 km, 10/2004, 1)       2
# (115,445 km, 09/2010, 3)       2
# (101,850 km, 04/2009, 2)       2
# (147,000 km, 05/2008, 1)       2
# (121,936 km, 02/2001, 3)       2
# (121,900 km, 02/2001, 3)       2
# (174,000 km, 07/2000, 2)       2
# (324,296 km, 02/2010, 2)       2
# (275,160 km, 03/2001, 9)       2
# (293,000 km, 05/2007, 2)       2
# (164,565 km, 07/2004, 1)       2
# (320,000 km, 03/2003, 2)       2
# (109,716 km, 12/2007, 1)       2
# (172,400 km, 04/2007, 1)       2
# (232,172 km, 01/2005, 2)       2
# (279,490 km, 03/2004, 3)       2
# (158,000 km, 05/2010, 2)       2
# (29,593 km, 06/2021, 1)        2
# (136,500 km, 12/2012, 1)       2
# (151,000 km, 02/2012, 2)       2
# (76,300 km, 09/1991, 2)        2
# (178,000 km, 10/2007, 1)       2
# (122,300 km, 05/1988, 4)       2
# (54,072 km, 01/1967, 1)        2
# (90,000 km, 02/2012, 2)        2
# (104,800 km, 03/1999, 2)       2
# (135,000 km, 11/1977, 2)       2
# (119,950 km, 06/2012, 2)       2
# (391,360 km, 11/1999, 3)       2
# (210,000 km, 01/2007, 3)       2
# (187,854 km, 01/2002, 9)       2
# (118,232 km, 12/2000, 2)       2
# (227,000 km, 02/2000, 1)       2
# (96,800 km, 07/2012, 1)        2
# (133,235 km, 06/2007, 2)       2
# (157,000 km, 04/2007, 3)       2
# (142,924 km, 09/2009, 3)       2
# (107,458 km, 03/2012, 3)       2
# (309,000 km, 04/2010, 1)       2
# (264,313 km, 09/2000, 6)       2
# (224,000 km, 05/1999, 3)       2
# (216,440 km, 03/1999, 6)       2
# (208,600 km, 01/2007, 2)       2
# (162,300 km, 09/2007, 3)       2
# (182,000 km, 10/2007, 2)       2
# (170,000 km, 05/1975, 2)       2
# (213,000 km, 06/2000, 1)       2
# (186,000 km, 03/2008, 2)       2
# (203,450 km, 01/2007, 3)       2
# (127,450 km, 06/2007, 3)       2
# (108,835 km, 03/2012, 2)       2
# (96,500 km, 07/2011, 2)        2
# (248,000 km, 03/2008, 2)       2
# (278,622 km, 04/1990, 2)       2
# (139,000 km, 03/2001, 1)       2
# (130,000 km, 01/1990, 1)       2
# (182,000 km, 11/1998, 1)       2
# (69,000 km, 07/2017, 1)        2
# (173,844 km, 06/2007, 4)       2
# (124,053 km, 05/2016, 1)       2
# (129,000 km, 12/1991, 2)       2
# (90,000 km, 05/2012, 1)        2
# (200,000 km, 05/1993, 3)       2
# (123,413 km, 08/2018, 1)       2
# (101,830 km, 09/2017, 1)       2
# (98,370 km, 05/2016, 1)        2
# (174,717 km, 02/2019, 1)       2
# (149,000 km, 11/2012, 1)       2
# (199,213 km, 03/2007, 3)       2
# (135,756 km, 01/2016, 2)       2
# (92,682 km, 02/2019, 1)        2
# (56,500 km, 11/2018, 1)        2
# (212,000 km, 02/2016, 1)       2
# (44,047 km, 02/2021, 1)        2
# (4,300 km, 12/2021, 1)         2
# (97,200 km, 03/2019, 1)        2
# (177,000 km, 03/2007, 1)       2
# (125,000 km, 04/2009, 1)       2
# (91,700 km, 07/1987, 1)        2
# (174,000 km, 06/1970, 1)       2
# (112,000 km, 05/2014, 2)       2
# (133,997 km, 01/1995, 1)       2
# (200,000 km, 03/2007, 3)       2
# (400,332 km, 04/2009, 6)       2
# (65,000 km, 11/2011, 2)        2
# (174,000 km, 09/2010, 1)       2
# (123,000 km, 11/2009, 2)       2
# (46,000 km, 07/1953, 3)        2
# (157,611 km, 06/2018, 1)       2
# (254,456 km, 08/2009, 2)       2
# (195,000 km, 07/2008, 2)       2
# (120,000 km, 06/2012, 1)       2
# (60,521 km, 09/2009, 3)        2
# (5,700 km, 01/1989, 3)         2
# (70,338 km, 07/1993, 1)        2
# (214,800 km, 02/1988, 3)       2
# (146,000 km, 04/2010, 1)       2
# (178,000 km, 06/2004, 2)       2
# (152,000 km, 02/2012, 4)       2
# (138,822 km, 01/2007, 2)       2
# (147,000 km, 06/2008, 2)       2
# (114,000 km, 01/2009, 1)       2
# (190,995 km, 01/2007, 3)       2
# (156,219 km, 05/2002, 4)       2
# (196,000 km, 01/2008, 1)       2
# (93,600 km, 12/2012, 2)        2
# (247,714 km, 06/2006, 4)       2
# (50,519 km, 06/2013, 1)        2
# (48,233 km, 11/2001, 1)        2
# (143,200 km, 03/2009, 3)       2
# (83,740 km, 06/2013, 2)        2
# (143,000 km, 07/2008, 2)       2
# (171,413 km, 02/2008, 3)       2
# (143,447 km, 11/2006, 2)       2
# (64,699 km, 03/2008, 4)        2
# (205,368 km, 01/2008, 3)       2
# (98,397 km, 04/2018, 1)        2
# (111,111 km, 07/1970, 3)       2
# (209,594 km, 07/2000, 3)       2
# (181,000 km, 03/2008, 2)       2
# (90,000 km, 01/2019, 1)        2
# (257,000 km, 10/2001, 1)       2
# (144,000 km, 10/2013, 3)       2
# (176,000 km, 05/2006, 3)       2
# (172,165 km, 08/2005, 3)       2
# (98,000 km, 03/2008, 2)        2
# (213,500 km, 03/2007, 2)       2
# (142,659 km, 06/2004, 2)       2
# (86,500 km, 11/2018, 1)        2
# (8,000 km, 11/2021, 1)         2
# (226,374 km, 01/2003, 2)       2
# (116,400 km, 07/2009, 2)       2
# (258,455 km, 04/2001, 6)       2
# (132,246 km, 04/2003, 3)       2
# (163,000 km, 05/2007, 2)       2
# (169,888 km, 03/2008, 3)       2
# (37,407 km, 05/2001, 1)        2
# (97,865 km, 06/2013, 1)        2
# (31,500 km, 03/2007, 2)        2
# (163,525 km, 12/2008, 1)       2
# (107,300 km, 11/2006, 2)       2
# (119,000 km, 06/2004, 3)       2
# (189,357 km, 04/2001, 6)       2
# (224,000 km, 05/2007, 2)       2
# (200,000 km, 03/2004, 1)       2
# (23,000 km, 05/2013, 2)        2
# (72,500 km, 10/2017, 2)        2
# (203,000 km, 03/2001, 3)       2
# (90,000 km, 10/2017, 2)        2
# (60,000 km, 08/1968, 5)        2
# (122,900 km, 03/2008, 2)       2
# (229,000 km, 07/1998, 2)       2
# (157,773 km, 10/1998, 9)       2
# (200,000 km, 10/1961, 4)       2
# (96,500 km, 04/1998, 2)        2
# (165,000 km, 02/2007, 2)       2
# (57,800 km, 04/2010, 1)        2
# (220,000 km, 07/2010, 1)       2
# (158,000 km, 09/2009, 3)       2
# (148,384 km, 02/2008, 1)       2
# (164,500 km, 06/2008, 2)       2
# (57,100 km, 07/2008, 1)        2
# (230,000 km, 05/2005, 1)       2
# (86,063 km, 11/2017, 1)        2
# (244,000 km, 01/2008, 2)       2
# (77,000 km, 01/2007, 1)        2
# (199,636 km, 06/2006, 2)       2
# (144,000 km, 03/2007, 2)       2
# (220,000 km, 04/2009, 2)       2
# (83,037 km, 05/2010, 2)        2
# (9,950 km, 03/2021, 1)         2
# (135,000 km, 03/2008, 1)       2
# (152,000 km, 11/2010, 2)       2
# (160,000 km, 04/2002, 2)       2
# (176,000 km, 10/2009, 2)       2
# (7,500 km, 08/2021, 1)         2
# (205,547 km, 01/2011, 1)       2
# (100 km, 03/2022, 1)           2
# (21,778 km, 02/2020, 1)        2
# (94,000 km, 02/2011, 2)        2
# (57,000 km, 01/2019, 1)        2
# (159,943 km, 11/2015, 1)       2
# (27,000 km, 09/2020, 1)        2
# (21,943 km, 05/2021, 1)        2
# (100 km, 10/2021, 1)           2
# (5,500 km, 04/2022, 1)         2
# (29,500 km, 04/2019, 2)        2
# (85,000 km, 01/1987, 1)        2
# (55,250 km, 05/2019, 1)        2
# (55,000 km, 01/2019, 1)        2
# (55,200 km, 09/2019, 1)        2
# (0 km, 12/2021, 1)             2
# (25,700 km, 08/2020, 1)        2
# (9,821 km, 03/2019, 2)         2
# (14,250 km, 08/2020, 1)        2
# (4,990 km, 01/2022, 1)         2
# (59,000 km, 01/2018, 1)        2
# (23,000 km, 01/2018, 1)        2
# (2,550 km, 12/2021, 1)         2
# (14,900 km, 12/2021, 1)        2
# (51,129 km, 09/2015, 2)        2
# (86,000 km, 03/2018, 1)        2
# (2 km, 09/2022, 1)             2
# (8,900 km, 06/2022, 1)         2
# (10 km, 08/2021, 1)            2
# (113,000 km, 05/2011, 1)       2
# (4,500 km, 05/2022, 1)         2
# (95,700 km, 08/2017, 1)        2
# (65,232 km, 02/2019, 2)        2
# (9,900 km, 01/2022, 1)         2
# (1 km, 12/2021, 1)             2
# (27,000 km, 07/2019, 1)        2
# (50 km, 02/2022, 1)            2
# (500 km, 06/2022, 1)           2
# (16,600 km, 07/2021, 1)        2
# (7,990 km, 03/2022, 1)         2
# (21,759 km, 10/2018, 1)        2
# (240,000 km, 01/2010, 1)       2
# (1,500 km, 04/2022, 1)         2
# (129,811 km, 09/2016, 1)       2
# (105,817 km, 02/2018, 1)       2
# (2,000 km, 08/2022, 1)         2
# (10 km, 07/2021, 1)            2
# (185,000 km, 11/1986, 2)       2
# (10 km, 12/2020, 1)            2
# (9,666 km, 03/2019, 1)         2
# (11,250 km, 11/2021, 1)        2
# (7,800 km, 12/2021, 1)         2
# (25,610 km, 07/2019, 1)        2
# (21,728 km, 06/2021, 1)        2
# (15,000 km, 02/2022, 1)        2
# (30,000 km, 03/2019, 1)        2
# (75,000 km, 08/2012, 1)        2
# (42,112 km, 07/2020, 1)        2
# (45,000 km, 12/2014, 1)        2
# (2,000 km, 05/2022, 1)         2
# (25 km, 08/2022, 1)            2
# (155,000 km, 05/2007, 2)       2
# (39,200 km, 04/2019, 1)        2
# (16,369 km, 05/2021, 1)        2
# (9,900 km, 10/2021, 1)         2
# (5,600 km, 12/2021, 1)         2
# (3,900 km, 05/2022, 1)         2
# (42,000 km, 07/2019, 1)        2
# (29,880 km, 11/2019, 1)        2
# (75 km, 07/2022, 1)            2
# (5 km, 10/2021, 1)             2
# (75,000 km, 07/2017, 2)        2
# (44,990 km, 02/2021, 1)        2
# (84,990 km, 02/2008, 1)        2
# (5,500 km, 12/2021, 1)         2
# (11,000 km, 08/2020, 1)        2
# (24,500 km, 06/2021, 1)        2
# (120,500 km, 09/2011, 2)       2
# (36,500 km, 12/2018, 1)        2
# (79,000 km, 07/2017, 1)        2
# (5 km, 09/2021, 1)             2
# (2,000 km, 01/2022, 1)         2
# (13,966 km, 08/2021, 1)        2
# (28,000 km, 05/1937, 2)        2
# (11,800 km, 07/2021, 1)        2
# (1,500 km, 01/2022, 1)         2
# (9,999 km, 02/2022, 1)         2
# (23,000 km, 07/2021, 1)        2
# (22,805 km, 03/2021, 1)        2
# (12,000 km, 11/2021, 1)        2
# (47,000 km, 09/2019, 1)        2
# (31,657 km, 09/2016, 1)        2
# (9,990 km, 07/2022, 1)         2
# (20,000 km, 06/2020, 1)        2
# (8 km, 04/2022, 2)             2
# (27,474 km, 10/2019, 1)        2
# (96,498 km, 10/2017, 1)        2
# (43,615 km, 02/2019, 1)        2
# (31,481 km, 07/2019, 1)        2
# (1,500 km, 12/2021, 1)         2
# (20 km, 03/2022, 1)            2
# (78,000 km, 07/2012, 1)        2
# (8,900 km, 07/2022, 1)         2
# (176,791 km, 01/2003, 3)       2
# (29,950 km, 10/2021, 1)        2
# (72,500 km, 07/2011, 3)        2
# (21,500 km, 07/2021, 1)        2
# (57,979 km, 09/2020, 2)        2
# (29,100 km, 07/2020, 2)        2
# (21,887 km, 04/2017, 1)        2
# (100,000 km, 07/2014, 2)       2
# (9,000 km, 02/2022, 1)         2
# (7,500 km, 11/2021, 1)         2
# (11,000 km, 10/2021, 1)        2
# (55,000 km, 04/2001, 1)        2
# (13,500 km, 09/2021, 1)        2
# (177,400 km, 01/2012, 3)       2
# (11,500 km, 07/2020, 1)        2
# (62,000 km, 03/2019, 1)        2
# (132,000 km, 10/1995, 2)       2
# (7,500 km, 02/2022, 1)         2
# (102,200 km, 07/2018, 1)       2
# (26,000 km, 03/2019, 1)        2
# (14,100 km, 06/2021, 1)        2
# (28,000 km, 02/2020, 1)        2
# (18,503 km, 11/2018, 2)        2
# (123,000 km, 06/2009, 2)       2
# (234,000 km, 02/2014, 1)       2
# (50,000 km, 07/2020, 1)        2
# (6 km, 03/2022, 1)             2
# (169,000 km, 12/2010, 1)       2
# (16 km, 04/2022, 2)            2
# (10,000 km, 04/2022, 1)        2
# (93,673 km, 07/2019, 1)        2
# (14,300 km, 06/2012, 3)        2
# (55,567 km, 05/2013, 1)        2
# (515 km, 12/2021, 1)           2
# (19,750 km, 03/2020, 2)        2
# (23,632 km, 05/2021, 1)        2
# (131,000 km, 12/2011, 2)       2
# (69,000 km, 05/2017, 2)        2
# (78,000 km, 10/2010, 2)        2
# (14,980 km, 03/2022, 1)        2
# (5,990 km, 04/2022, 1)         2
# (108,941 km, 10/2014, 8)       2
# (19,000 km, 01/2020, 1)        2
# (24,000 km, 09/2017, 1)        2
# (20,475 km, 09/2021, 1)        2
# (100,000 km, 01/2018, 2)       2
# (2,500 km, 04/2022, 1)         2
# (55,000 km, 07/2020, 1)        2
# (116,678 km, 06/2016, 1)       2
# (50,500 km, 08/2017, 1)        2
# (10 km, 10/2022, 1)            2
# (54,282 km, 07/2018, 1)        2
# (643 km, 10/2021, 1)           2
# (235,680 km, 12/2014, 4)       2
# (151,861 km, 09/2015, 1)       2
# (129,841 km, 07/2015, 4)       2
# (142,847 km, 01/2013, 3)       2
# (64,000 km, 07/2017, 1)        2
# (17,200 km, 05/2021, 1)        2
# (170,153 km, 09/2015, 1)       2
# (5,100 km, 09/2021, 1)         2
# (10,500 km, 06/2021, 1)        2
# (6,500 km, 05/2022, 1)         2
# (21,512 km, 11/2020, 1)        2
# (5,100 km, 09/2022, 1)         2
# (87,814 km, 09/2017, 1)        2
# (106,789 km, 12/2016, 2)       2
# (60,000 km, 07/2018, 1)        2
# (19,400 km, 07/2019, 1)        2
# (10,350 km, 09/2021, 1)        2
# (51,800 km, 07/2019, 1)        2
# (66,782 km, 03/2019, 1)        2
# (20,000 km, 03/2021, 1)        2
# (35,000 km, 11/2018, 2)        2
# (75,598 km, 08/2018, 1)        2
# (172,059 km, 10/2012, 2)       2
# (229,538 km, 06/2007, 2)       2
# (110,000 km, 04/2017, 1)       2
# (44,700 km, 04/2019, 1)        2
# (68,339 km, 01/2019, 1)        2
# (111,615 km, 07/2018, 2)       2
# (139,826 km, 05/2017, 1)       2
# (70,806 km, 10/2017, 1)        2
# (112,833 km, 11/2014, 1)       2
# (167,230 km, 09/2008, 5)       2
# (32,047 km, 06/2018, 5)        2
# (29,752 km, 11/2018, 1)        2
# (65,182 km, 12/2018, 2)        2
# (56,606 km, 10/2018, 6)        2
# (39,533 km, 09/2018, 2)        2
# (128,058 km, 09/2018, 2)       2
# (48,548 km, 08/2017, 2)        2
# (76,071 km, 02/2018, 1)        2
# (22,352 km, 10/2019, 2)        2
# (175,356 km, 04/2018, 2)       2
# (175,580 km, 12/2015, 3)       2
# (137,763 km, 07/2015, 3)       2
# (202,447 km, 07/2015, 1)       2
# (165,105 km, 11/2016, 2)       2
# (104,925 km, 12/2013, 1)       2
# (187,644 km, 05/2013, 2)       2
# (351 km, 05/2012, 1)           2
# (176,445 km, 03/2018, 2)       2
# (177,000 km, 01/2007, 1)       2
# (147,287 km, 01/2009, 1)       2
# (125,680 km, 01/2019, 2)       2
# (101,061 km, 02/2016, 1)       2
# (102,769 km, 01/2007, 2)       2
# (180,914 km, 12/2015, 3)       2
# (113,115 km, 12/2014, 1)       2
# (206,202 km, 11/2013, 3)       2
# (93,214 km, 03/2018, 1)        2
# (95,721 km, 06/1996, 2)        2
# (32,709 km, 12/2019, 1)        2
# (1,500 km, 03/2022, 1)         2
# (1,500 km, 02/2022, 1)         2
# (3,000 km, 05/2022, 1)         2
# (74,000 km, 03/2016, 1)        2
# (6,001 km, 05/2022, 1)         2
# (20 km, 10/2021, 1)            2
# (8,500 km, 12/2021, 1)         2
# (44,380 km, 03/2013, 1)        2
# (20 km, 02/2022, 1)            2
# (88,000 km, 03/2018, 1)        2
# (4,999 km, 05/2022, 1)         2
# (79,603 km, 02/2014, 1)        2
# (14 km, 05/2022, 1)            2
# (18,550 km, 07/2021, 1)        2
# (70,000 km, 05/2018, 1)        2
# (4,500 km, 06/2021, 1)         2
# (15 km, 11/2021, 1)            2
# (8,900 km, 01/2020, 1)         2
# (6,000 km, 05/2022, 1)         2
# (40,700 km, 02/2020, 1)        2
# (60,000 km, 01/2020, 2)        2
# (1,001 km, 08/2021, 1)         2
# (45,546 km, 08/2020, 1)        2
# (8,660 km, 12/2021, 1)         2
# (5 km, 03/2022, 1)             2
# (5,900 km, 06/2022, 1)         2
# (7,740 km, 05/2021, 1)         2
# (50 km, 09/2021, 1)            2
# (63,434 km, 06/2019, 2)        2
# (800 km, 05/2022, 1)           2
# (57,095 km, 07/2018, 1)        2
# (12,438 km, 05/2021, 1)        2
# (4,500 km, 07/2021, 1)         2
# (36,082 km, 01/2019, 1)        2
# (88,750 km, 02/2019, 1)        2
# (27,000 km, 01/2018, 1)        2
# (49,500 km, 02/2019, 1)        2
# (340 km, 08/2022, 1)           2
# (11,000 km, 08/2021, 1)        2
# (120,000 km, 04/2018, 1)       2
# (5,250 km, 11/2021, 1)         2
# (1,400 km, 11/2021, 1)         2
# (100 km, 05/2022, 1)           2
# (52,944 km, 02/2017, 1)        2
# (22,000 km, 03/2020, 1)        2
# (20 km, 12/2021, 1)            2
# (13,371 km, 05/2021, 1)        2
# (22,500 km, 08/2020, 1)        2
# (150 km, 11/2021, 1)           2
# (150,000 km, 06/1997, 1)       2
# (1,555 km, 07/2022, 1)         2
# (29,200 km, 08/2018, 2)        2
# (108,165 km, 03/2014, 3)       2
# (2,500 km, 07/2021, 1)         2
# (2 km, 08/2022, 1)             2
# (8,500 km, 09/2021, 1)         2
# (13,801 km, 01/2020, 1)        2
# (20 km, 01/2022, 1)            2
# (22,410 km, 06/2021, 1)        2
# (23,000 km, 10/2020, 1)        2
# (65,300 km, 09/2018, 1)        2
# (61,240 km, 06/2019, 2)        2
# (29,990 km, 04/2021, 2)        2
# (22,100 km, 01/2020, 1)        2
# (3,568 km, 12/2021, 1)         2
# (150,884 km, 08/2006, 5)       2
# (9,548 km, 02/2022, 1)         2
# (12,500 km, 04/2022, 1)        2
# (38,854 km, 10/2021, 1)        2
# (51,843 km, 10/2018, 1)        2
# (132,933 km, 10/2006, 2)       2
# (93,016 km, 07/2018, 2)        2
# (74,500 km, 08/2019, 1)        2
# (20,626 km, 12/2020, 2)        2
# (228,157 km, 02/2008, 4)       2
# (134,441 km, 05/2008, 1)       2
# (27,000 km, 08/2019, 1)        2
# (21,500 km, 12/2021, 1)        2
# (57,074 km, 07/2017, 2)        2
# (12,000 km, 10/2021, 1)        2
# (22,165 km, 03/2020, 1)        2
# (56,656 km, 10/2020, 1)        2
# (13,125 km, 07/2020, 1)        2
# (14,547 km, 02/2019, 1)        2
# (27,554 km, 05/2019, 1)        2
# (28,500 km, 09/2020, 2)        2
# (19,190 km, 02/2020, 1)        2
# (76,900 km, 08/2016, 2)        2
# (36,200 km, 07/2019, 1)        2
# (105,000 km, 12/2016, 2)       2
# (2,287 km, 03/2021, 1)         2
# (21,600 km, 12/2021, 1)        2
# (75,500 km, 03/2019, 1)        2
# (12,900 km, 10/2021, 1)        2
# (26,338 km, 02/2020, 1)        2
# (28,000 km, 06/2020, 1)        2
# (78,736 km, 03/2018, 2)        2
# (3,736 km, 03/2021, 1)         2
# (5,880 km, 02/2021, 1)         2
# (18,298 km, 11/2016, 1)        2
# (53,780 km, 10/2016, 1)        2
# (60,955 km, 09/2017, 1)        2
# (42,900 km, 11/2020, 1)        2
# (44,191 km, 10/2018, 1)        2
# (59,362 km, 01/2019, 1)        2
# (74,566 km, 08/2019, 1)        2
# (23,000 km, 11/2021, 1)        2
# (82,092 km, 03/2019, 1)        2
# (70,149 km, 05/2019, 1)        2
# (2,900 km, 12/2021, 1)         2
# (33,199 km, 02/2019, 1)        2
# (66,370 km, 08/2019, 1)        2
# (22,365 km, 10/2019, 1)        2
# (75,124 km, 11/2018, 1)        2
# (85,000 km, 12/2018, 1)        2
# (38,000 km, 05/2019, 1)        2
# (149,923 km, 03/2016, 1)       2
# (51,044 km, 07/2017, 2)        2
# (19,548 km, 07/2021, 1)        2
# (45,189 km, 05/2019, 1)        2
# (56,000 km, 07/2020, 1)        2
# (41,580 km, 05/2019, 1)        2
# (2,500 km, 08/2022, 1)         2
# (37,000 km, 06/2019, 1)        2
# (47,700 km, 11/2018, 1)        2
# (64,460 km, 01/2019, 1)        2
# (59,900 km, 01/2021, 1)        2
# (29,589 km, 09/2019, 1)        2
# (76,663 km, 12/2018, 1)        2
# (29,868 km, 12/2019, 2)        2
# (81,874 km, 06/2018, 1)        2
# (48,358 km, 07/2017, 1)        2
# (23,574 km, 04/2021, 1)        2
# (201 km, 08/2022, 1)           2
# (11,200 km, 12/2021, 1)        2
# (3,800 km, 05/2021, 1)         2
# (58,449 km, 12/2018, 1)        2
# (16,463 km, 10/2020, 1)        2
# (84,997 km, 10/2018, 2)        2
# (65,000 km, 02/2016, 1)        2
# (42,545 km, 01/2020, 1)        2
# (66,000 km, 06/2020, 1)        2
# (4,750 km, 03/2020, 1)         2
# (97,600 km, 05/2019, 1)        2
# (22,240 km, 04/2020, 1)        2
# (9,990 km, 02/2022, 1)         2
# (112,918 km, 10/2012, 1)       2
# (300 km, 01/2022, 1)           2
# (3,990 km, 12/2021, 1)         2
# (16,390 km, 06/2021, 1)        2
# (7,727 km, 03/2021, 1)         2
# (58,805 km, 09/2019, 1)        2
# (19,700 km, 12/2019, 1)        2
# (107,415 km, 05/2019, 1)       2
# (116,550 km, 07/2019, 1)       2
# (7,200 km, 12/2021, 1)         2
# (65,546 km, 01/2019, 1)        2
# (23,434 km, 03/2021, 1)        2
# (62,400 km, 01/2019, 2)        2
# (50,811 km, 10/2019, 1)        2
# (44,377 km, 11/2019, 1)        2
# (81,976 km, 09/2019, 1)        2
# (3,001 km, 07/2022, 1)         2
# (24,858 km, 04/2020, 1)        2
# (24,700 km, 03/2019, 1)        2
# (79,450 km, 08/2019, 1)        2
# (31,990 km, 04/2020, 1)        2
# (9,700 km, 07/2020, 1)         2
# (10,800 km, 12/2021, 1)        2
# (10,990 km, 12/2021, 1)        2
# (116,000 km, 01/2019, 1)       2
# (201,000 km, 06/2001, 2)       2
# (50,718 km, 05/2020, 1)        2
# (58,398 km, 07/2019, 1)        2
# (30,246 km, 02/2019, 1)        2
# (62,914 km, 02/2020, 1)        2
# (51,410 km, 12/2016, 1)        2
# (72,684 km, 11/2017, 2)        2
# (32,515 km, 12/2016, 1)        2
# (51,662 km, 05/2019, 1)        2
# (71,620 km, 07/2018, 1)        2
# (89,000 km, 10/2018, 1)        2
# (59,750 km, 04/2019, 1)        2
# (80,000 km, 02/2018, 1)        2
# (9,300 km, 12/2021, 1)         2
# (22,058 km, 06/2019, 1)        2
# (1,000 km, 05/2022, 1)         2
# (41,098 km, 10/2018, 1)        2
# (17,852 km, 07/2020, 1)        2
# (213 km, 11/2021, 1)           2
# (117,300 km, 06/2019, 2)       2
# (44,914 km, 12/2020, 2)        2
# (12,000 km, 09/2020, 1)        2
# (45,104 km, 06/2019, 1)        2
# (75,400 km, 10/2016, 4)        2
# (117,042 km, 11/2013, 2)       2
# (84,503 km, 04/2018, 2)        2
# (8,400 km, 01/2022, 1)         2
# (53,343 km, 04/2018, 1)        2
# (49,700 km, 05/2019, 1)        2
# (104,752 km, 02/2019, 1)       2
# (10 km, 03/2021, 1)            2
# (37,566 km, 05/2020, 1)        2
# (0 km, 08/2022, 1)             2
# (95,542 km, 12/2018, 1)        2
# (127,000 km, 07/2014, 1)       2
# (4,500 km, 08/2022, 1)         2
# (77,296 km, 01/2019, 1)        2
# (10,750 km, 03/2021, 1)        2
# (31,380 km, 02/2019, 1)        2
# (95,000 km, 08/2018, 1)        2
# (221 km, 11/2021, 1)           2
# (132,585 km, 03/2010, 3)       2
# (23,300 km, 08/2020, 1)        2
# (12,100 km, 12/2021, 1)        2
# (47,390 km, 09/2017, 1)        2
# (71,000 km, 10/2016, 1)        2
# (44,269 km, 07/2019, 1)        2
# (32,968 km, 11/2019, 1)        2
# (96,000 km, 09/2017, 1)        2
# (57,396 km, 01/2019, 1)        2
# (343,701 km, 02/2013, 3)       2
# (345,000 km, 04/1991, 5)       2
# (170,836 km, 04/2014, 4)       2
# (198,480 km, 12/2014, 4)       2
# (91,500 km, 10/2018, 1)        2
# (239,991 km, 09/2015, 1)       2
# (180,609 km, 06/2019, 1)       2
# (200,000 km, 12/2017, 1)       2
# (150,222 km, 11/2015, 1)       2
# (128,500 km, 04/2016, 3)       2
# (121,169 km, 05/2018, 1)       2
# (189,495 km, 02/2011, 2)       2
# (10,000 km, 08/2022, 1)        2
# (172,000 km, 02/1999, 2)       2
# (135,628 km, 03/2018, 1)       2
# (285,350 km, 06/2014, 3)       2
# (230,000 km, 09/2013, 1)       2
# (66,281 km, 02/2020, 1)        2
# (77,800 km, 06/2013, 1)        2
# (342,514 km, 07/1997, 12)      2
# (107,018 km, 06/2018, 1)       2
# (78,258 km, 10/2013, 1)        2
# (132,459 km, 01/2012, 1)       2
# (97,707 km, 07/2018, 1)        2
# (232,475 km, 08/2015, 2)       2
# (348,785 km, 11/1997, 8)       2
# (203,481 km, 01/2016, 1)       2
# (150,000 km, 04/2016, 1)       2
# (232,600 km, 11/1995, 4)       2
# (156,184 km, 02/2019, 1)       2
# (111,558 km, 04/2003, 2)       2
# (90,600 km, 03/2017, 1)        2
# (17,500 km, 03/2018, 1)        2
# (7,350 km, 07/2021, 1)         2
# (29,600 km, 07/2019, 1)        2
# (433,850 km, 03/2007, 7)       2
# (12,800 km, 03/2021, 2)        2
# (348,547 km, 02/2002, 3)       2
# (54,000 km, 05/2014, 3)        2
# (48,000 km, 02/2018, 1)        2
# (40,600 km, 06/2019, 1)        2
# (99 km, 09/2022, 1)            2
# (99 km, 11/2021, 1)            2
# (8,000 km, 06/2021, 1)         2
# (500 km, 03/2022, 1)           2
# (23,800 km, 12/2021, 1)        2
# (55,045 km, 12/2018, 1)        2
# (12,700 km, 08/2019, 1)        2
# (500 km, 05/2022, 1)           2
# (12 km, 09/2022, 1)            2
# (14,200 km, 12/2021, 1)        2
# (1,500 km, 05/2021, 1)         2
# (65,308 km, 09/2013, 1)        2
# (15 km, 05/2021, 1)            2
# (12,000 km, 12/2021, 1)        2
# (12,644 km, 02/2022, 1)        2
# (450 km, 02/2022, 1)           2
# (42,794 km, 02/2019, 1)        2
# (365,058 km, 10/2001, 4)       2
# (143,550 km, 01/2016, 1)       2
# (9,750 km, 01/2021, 1)         2
# (149,047 km, 11/2013, 1)       2
# (195,000 km, 04/2018, 1)       2
# (178,568 km, 12/2013, 2)       2
# (9,800 km, 12/2021, 1)         2
# (78,000 km, 10/2017, 1)        2
# (13,900 km, 12/2021, 1)        2
# (29,901 km, 10/2020, 1)        2
# (7,000 km, 02/2022, 1)         2
# (11,999 km, 12/2021, 1)        2
# (39,000 km, 05/2003, 1)        2
# (3,001 km, 08/2022, 1)         2
# (172,106 km, 10/2016, 1)       2
# (23,400 km, 09/2021, 1)        2
# (54,550 km, 05/2020, 1)        2
# (75,027 km, 01/2019, 1)        2
# (8,244 km, 10/2021, 1)         2
# (55,101 km, 06/2018, 1)        2
# (17,200 km, 09/2021, 1)        2
# (14,967 km, 06/2020, 1)        2
# (65,504 km, 01/2019, 1)        2
# (26,515 km, 03/2019, 2)        2
# (2,620 km, 02/2021, 1)         2
# (26,729 km, 07/2020, 1)        2
# (15,000 km, 05/2021, 1)        2
# (46,768 km, 12/2020, 2)        2
# (15,278 km, 08/2021, 1)        2
# (800 km, 08/2022, 1)           2
# (78,502 km, 01/2018, 2)        2
# (13,655 km, 12/2020, 1)        2
# (14,104 km, 09/2021, 1)        2
# (159,526 km, 03/2008, 4)       2
# (6,800 km, 12/2020, 1)         2
# (20,532 km, 03/2021, 1)        2
# (85,869 km, 05/2018, 2)        2
# (43,301 km, 05/2019, 1)        2
# (27,116 km, 09/2020, 2)        2
# (39,064 km, 12/2019, 1)        2
# (62,326 km, 04/2018, 2)        2
# (28,168 km, 04/2019, 1)        2
# (35,000 km, 12/2019, 1)        2
# (73,800 km, 06/2019, 1)        2
# (5,964 km, 01/2021, 1)         2
# (23,500 km, 08/2020, 1)        2
# (38,600 km, 04/2019, 2)        2
# (41,864 km, 03/2019, 2)        2
# (70,238 km, 10/2018, 1)        2
# (7,000 km, 10/2021, 1)         2
# (12,300 km, 10/2021, 1)        2
# (39,378 km, 05/2018, 2)        2
# (121,202 km, 01/1998, 2)       2
# (125,000 km, 12/2009, 1)       2
# (13,187 km, 08/2021, 1)        2
# (12,354 km, 03/2022, 1)        2
# (36,887 km, 06/2018, 2)        2
# (38,205 km, 11/2020, 1)        2
# (12,000 km, 11/2020, 1)        2
# (11,190 km, 01/2021, 2)        2
# (50,773 km, 04/2017, 1)        2
# (50,177 km, 11/2017, 2)        2
# (97,009 km, 09/2019, 1)        2
# (87,572 km, 08/2018, 2)        2
# (56,384 km, 12/2017, 2)        2
# (93,650 km, 05/2019, 2)        2
# (180,275 km, 12/2010, 2)       2
# (258,100 km, 07/2009, 2)       2
# (96,200 km, 01/1973, 2)        2
# (16,251 km, 08/2021, 1)        2
# (8,000 km, 07/2021, 1)         2
# (9,500 km, 06/2022, 1)         2
# (19,919 km, 09/2021, 1)        2
# (15,658 km, 10/2021, 1)        2
# (15 km, 02/2022, 1)            2
# (12,585 km, 11/2021, 1)        2
# (6,653 km, 05/2022, 1)         2
# (52,987 km, 12/2019, 2)        2
# (49,844 km, 01/2020, 1)        2
# (82,084 km, 07/2019, 1)        2
# (8,800 km, 10/2021, 1)         2
# (58,196 km, 02/2018, 2)        2
# (23,603 km, 10/2019, 1)        2
# (9,679 km, 02/2022, 1)         2
# (10,183 km, 06/2021, 1)        2
# (32,991 km, 06/2020, 1)        2
# (7,475 km, 10/2020, 1)         2
# (76,500 km, 06/2017, 1)        2
# (61,474 km, 08/2018, 1)        2
# (125,000 km, 12/2016, 1)       2
# (39,072 km, 06/2018, 2)        2
# (36,528 km, 11/2019, 1)        2
# (72,000 km, 09/2017, 1)        2
# (93,672 km, 09/2019, 1)        2
# (75,119 km, 06/2018, 1)        2
# (75,730 km, 09/2015, 1)        2
# (32,750 km, 09/2020, 1)        2
# (71,000 km, 02/2018, 1)        2
# (30,789 km, 06/2019, 1)        2
# (91,847 km, 07/2018, 1)        2
# (82,236 km, 03/2019, 1)        2
# (47,098 km, 11/2018, 1)        2
# (131,460 km, 05/2018, 1)       2
# (58,924 km, 10/2017, 1)        2
# (46,657 km, 03/2019, 1)        2
# (52,800 km, 09/2019, 2)        2
# (49,150 km, 03/2021, 1)        2
# (88,000 km, 02/2018, 2)        2
# (63,200 km, 01/2019, 1)        2
# (94,850 km, 12/2017, 1)        2
# (31,111 km, 04/2019, 1)        2
# (12,800 km, 10/2020, 1)        2
# (29,300 km, 12/2018, 1)        2
# (72,000 km, 02/2019, 1)        2
# (116,750 km, 06/2020, 1)       2
# (23,989 km, 04/2021, 1)        2
# (50,972 km, 08/2019, 1)        2
# (75,600 km, 11/2018, 1)        2
# (91,000 km, 12/2015, 2)        2
# (59,500 km, 09/2020, 2)        2
# (53,793 km, 02/2019, 1)        2
# (2,242 km, 12/2021, 1)         2
# (55,000 km, 05/2019, 2)        2
# (9,500 km, 10/2021, 1)         2
# (28,545 km, 12/2021, 1)        2
# (85,500 km, 06/2017, 2)        2
# (89,000 km, 04/2016, 2)        2
# (27,639 km, 12/2021, 1)        2
# (79,266 km, 12/2018, 1)        2
# (28,300 km, 07/2020, 2)        2
# (45,000 km, 07/2019, 1)        2
# (35,760 km, 07/2019, 1)        2
# (121,900 km, 03/2018, 1)       2
# (42,326 km, 03/2020, 1)        2
# (25,500 km, 10/2017, 1)        2
# (11,257 km, 08/2019, 1)        2
# (12,500 km, 12/2020, 1)        2
# (75,900 km, 11/2018, 1)        2
# (100,000 km, 06/2016, 1)       2
# (7,500 km, 09/2022, 1)         2
# (83,651 km, 05/2019, 1)        2
# (91,383 km, 01/2019, 1)        2
# (33,000 km, 01/2019, 1)        2
# (42,590 km, 05/2019, 1)        2
# (70,000 km, 03/2014, 2)        2
# (24,508 km, 03/2020, 1)        2
# (58,657 km, 09/2019, 1)        2
# (15,000 km, 01/2022, 1)        2
# (32,752 km, 12/2018, 2)        2
# (70,452 km, 07/2016, 2)        2
# (79,911 km, 07/2017, 1)        2
# (52,750 km, 09/2018, 2)        2
# (11,953 km, 01/2021, 1)        2
# (45,897 km, 10/2017, 1)        2
# (78,485 km, 07/2019, 1)        2
# (54,800 km, 10/2018, 1)        2
# (12,330 km, 04/2021, 2)        2
# (64,000 km, 02/2019, 1)        2
# (30,028 km, 12/2019, 1)        2
# (44,000 km, 12/2018, 1)        2
# (24,047 km, 04/2021, 1)        2
# (49,200 km, 03/2019, 2)        2
# (18,323 km, 08/2019, 1)        2
# (22,900 km, 01/2019, 1)        2
# (8,749 km, 10/2021, 1)         2
# (99,600 km, 11/2018, 1)        2
# (78,207 km, 02/2019, 1)        2
# (56,764 km, 07/2019, 1)        2
# (4,763 km, 10/2021, 2)         2
# (76,150 km, 05/2019, 1)        2
# (66,868 km, 07/2017, 2)        2
# (48,837 km, 02/2018, 2)        2
# (48,696 km, 05/2020, 1)        2
# (14,026 km, 11/2021, 1)        2
# (4,400 km, 12/2021, 1)         2
# (91,300 km, 12/2011, 2)        2
# (100,299 km, 03/2017, 2)       2
# (24,305 km, 02/2020, 2)        2
# (52,806 km, 03/2019, 1)        2
# (90,009 km, 03/2019, 1)        2
# (98,750 km, 02/2019, 1)        2
# (90,788 km, 05/2019, 1)        2
# (82,000 km, 01/2019, 1)        2
# (129,837 km, 06/2019, 1)       2
# (21,179 km, 10/2021, 1)        2
# (91,441 km, 09/2017, 2)        2
# (82,480 km, 10/2018, 1)        2
# (55,642 km, 07/2019, 1)        2
# (16,000 km, 12/2021, 1)        2
# (44,812 km, 04/2019, 1)        2
# (90,750 km, 07/2019, 1)        2
# (59,000 km, 06/2019, 1)        2
# (81,181 km, 11/2015, 2)        2
# (56,969 km, 09/2018, 1)        2
# (188,369 km, 09/2016, 1)       2
# (71,500 km, 04/2018, 2)        2
# (9,500 km, 07/2022, 1)         2
# (150 km, 04/2022, 1)           2
# (97,884 km, 06/2019, 1)        2
# (108,569 km, 07/2019, 1)       2
# (23,900 km, 11/2018, 1)        2
# (6,000 km, 03/2022, 1)         2
# (57,000 km, 07/2019, 1)        2
# (124,000 km, 09/2013, 3)       2
# (44,667 km, 09/2018, 1)        2
# (148,000 km, 12/2006, 3)       2
# (110,326 km, 09/2015, 2)       2
# (60,000 km, 02/2019, 1)        2
# (64,138 km, 11/2017, 1)        2
# (64,723 km, 05/2019, 1)        2
# (39,490 km, 09/2019, 1)        2
# (15,990 km, 02/2021, 1)        2
# (114,500 km, 07/2015, 2)       2
# (299,990 km, 01/2010, 2)       2
# (22,021 km, 07/2020, 1)        2
# (6,900 km, 10/2021, 1)         2
# (61,448 km, 07/2019, 1)        2
# (22,554 km, 09/2020, 1)        2
# (42,060 km, 09/2020, 1)        2
# (9,100 km, 12/2021, 1)         2
# (72,680 km, 08/2015, 2)        2
# (16,400 km, 12/2021, 1)        2
# (10,962 km, 01/2022, 1)        2
# (85,800 km, 04/2018, 1)        2
# (24,600 km, 09/2019, 1)        2
# (5,163 km, 01/2022, 1)         2
# (27,000 km, 07/2018, 1)        2
# (58,400 km, 06/2013, 2)        2
# (20,000 km, 08/2018, 2)        2
# (14,500 km, 12/2021, 1)        2
# (6,078 km, 12/2021, 1)         2
# (76,990 km, 05/2019, 1)        2
# (48,776 km, 12/2019, 2)        2
# (138,600 km, 07/2019, 1)       2
# (252,687 km, 09/2008, 3)       2
# (3,201 km, 12/2021, 1)         2
# (82,940 km, 02/2020, 1)        2
# (62,950 km, 09/2017, 1)        2
# (67,667 km, 05/2020, 1)        2
# (45,000 km, 05/2019, 1)        2
# (21,680 km, 02/2020, 1)        2
# (40,370 km, 06/2019, 1)        2
# (19,620 km, 11/2021, 1)        2
# (39,026 km, 07/2019, 1)        2
# (54,000 km, 10/2019, 1)        2
# (23,657 km, 06/2021, 2)        2
# (17,750 km, 01/2021, 1)        2
# (5,972 km, 08/2020, 1)         2
# (11,697 km, 08/2020, 1)        2
# (152,700 km, 06/2015, 2)       2
# (100,521 km, 07/2019, 1)       2
# (66,882 km, 09/2018, 1)        2
# (44,500 km, 12/2018, 2)        2
# (48,370 km, 10/2018, 1)        2
# (5,824 km, 09/2021, 1)         2
# (23,361 km, 03/2021, 2)        2
# (58,000 km, 12/2018, 1)        2
# (15,900 km, 12/2021, 1)        2
# (49,800 km, 02/2019, 2)        2
# (90,345 km, 03/2018, 1)        2
# (128,875 km, 02/2019, 1)       2
# (74,500 km, 12/2019, 1)        2
# (148,612 km, 01/2019, 1)       2
# (43,300 km, 01/2019, 1)        2
# (25,950 km, 06/2017, 2)        2
# (11,007 km, 11/2020, 1)        2
# (28,900 km, 12/2019, 1)        2
# (63,054 km, 09/2020, 1)        2
# (49,000 km, 05/2019, 1)        2
# (31,656 km, 04/2019, 1)        2
# (1,494 km, 04/2021, 1)         2
# (92,700 km, 04/2020, 1)        2
# (92,235 km, 02/2018, 1)        2
# (141,000 km, 05/2017, 1)       2
# (19,500 km, 11/2019, 1)        2
# (172,000 km, 03/2012, 1)       2
# (12,485 km, 03/2022, 1)        2
# (94,358 km, 09/2019, 1)        2
# (99,900 km, 01/2015, 2)        2
# (107,980 km, 07/2015, 2)       2
# (265,050 km, 10/2015, 1)       2
# (67,500 km, 05/2016, 1)        2
# (74,401 km, 01/2017, 1)        2
# (52,147 km, 04/2017, 1)        2
# (6,815 km, 12/2021, 1)         2
# (12,469 km, 06/2020, 1)        2
# (52,000 km, 03/2021, 1)        2
# (17,313 km, 06/2020, 1)        2
# (62,000 km, 02/2014, 2)        2
# (32,417 km, 02/2019, 2)        2
# (33,950 km, 03/2019, 1)        2
# (16,500 km, 08/2021, 1)        2
# (19,241 km, 12/2021, 1)        2
# (8,256 km, 01/2022, 1)         2
# (44,000 km, 09/2019, 1)        2
# (24,255 km, 02/2021, 1)        2
# (15,849 km, 03/2021, 1)        2
# (9,844 km, 12/2021, 1)         2
# (36,450 km, 05/2019, 1)        2
# (20,063 km, 03/2020, 1)        2
# (44,395 km, 11/2018, 1)        2
# (53,100 km, 03/2019, 1)        2
# (17,860 km, 01/2022, 1)        2
# (2,385 km, 12/2021, 1)         2
# (162,617 km, 11/2015, 1)       2
# (78,211 km, 05/2019, 1)        2
# (353,453 km, 01/2008, 3)       2
# (48,438 km, 07/2019, 1)        2
# (120,752 km, 02/2015, 1)       2
# (112,934 km, 03/2019, 1)       2
# (25,600 km, 09/2019, 1)        2
# (90,599 km, 12/2016, 1)        2
# (40,000 km, 10/2018, 2)        2
# (31,588 km, 02/2019, 1)        2
# (49,445 km, 02/2019, 1)        2
# (34,350 km, 10/2019, 1)        2
# (139,803 km, 10/2017, 1)       2
# (120,000 km, 07/2018, 1)       2
# (25,200 km, 05/2019, 1)        2
# (85,000 km, 12/2016, 1)        2
# (15,197 km, 07/2020, 1)        2
# (66,864 km, 05/2019, 1)        2
# (126,603 km, 05/2015, 1)       2
# (42,000 km, 05/2020, 1)        2
# (124,800 km, 02/2016, 1)       2
# (74,200 km, 07/2017, 1)        2
# (104,900 km, 03/2019, 1)       2
# (111,332 km, 03/2018, 1)       2
# (69,000 km, 03/2019, 1)        2
# (21,000 km, 11/2021, 1)        2
# (28,400 km, 11/2018, 2)        2
# (105,000 km, 06/2015, 2)       2
# (112,000 km, 12/2016, 1)       2
# (21,946 km, 07/2020, 1)        2
# (16,714 km, 10/2020, 1)        2
# (95,689 km, 10/2019, 1)        2
# (30,000 km, 11/2019, 1)        2
# (89,759 km, 07/2019, 1)        2
# (46,990 km, 10/2018, 1)        2
# (54,034 km, 06/2020, 1)        2
# (93,133 km, 02/2019, 1)        2
# (191,900 km, 03/2019, 1)       2
# (18,846 km, 08/2020, 1)        2
# (49,700 km, 07/2019, 1)        2
# (95,037 km, 09/2018, 1)        2
# (75,000 km, 10/2017, 1)        2
# (63,500 km, 04/2020, 1)        2
# (7,900 km, 09/2022, 1)         2
# (31,700 km, 12/2019, 1)        2
# (19,950 km, 08/2021, 1)        2
# (32,750 km, 03/2019, 1)        2
# (175,000 km, 04/2017, 2)       2
# (3,300 km, 12/2021, 1)         2
# (130,000 km, 10/2017, 1)       2
# (77,742 km, 05/2019, 1)        2
# (28,900 km, 07/2021, 1)        2
# (43,700 km, 07/2018, 1)        2
# (30,750 km, 05/2020, 2)        2
# (52,500 km, 04/2019, 1)        2
# (20,000 km, 04/2022, 1)        2
# (76,871 km, 07/2018, 2)        2
# (9,187 km, 12/2021, 1)         2
# (59,613 km, 05/2019, 1)        2
# (4,000 km, 10/2021, 1)         2
# (1,435 km, 09/2021, 1)         2
# (68,000 km, 11/2018, 1)        2
# (71,300 km, 01/2019, 1)        2
# (66,057 km, 11/2017, 1)        2
# (6,541 km, 12/2021, 1)         2
# (80,470 km, 07/2019, 1)        2
# (25,718 km, 05/2019, 1)        2
# (64,200 km, 01/2019, 1)        2
# (11,731 km, 06/2021, 1)        2
# (38,701 km, 07/2019, 1)        2
# (106,800 km, 02/2019, 1)       2
# (16,000 km, 09/2021, 1)        2
# (71,500 km, 06/2018, 1)        2
# (76,169 km, 08/2018, 1)        2
# (17,816 km, 02/2019, 1)        2
# (25,000 km, 11/2017, 1)        2
# (74,868 km, 04/2019, 1)        2
# (59,165 km, 07/2019, 1)        2
# (87,026 km, 07/2018, 2)        2
# (82,500 km, 11/2017, 2)        2
# (30,263 km, 01/2019, 1)        2
# (228,400 km, 05/1993, 4)       1
# (91,868 km, 03/2013, 2)        1
# (43,000 km, 02/2002, 1)        1
# (65,505 km, 12/2017, 1)        1
# (60,000 km, 07/1993, 2)        1
# (136,590 km, 11/2014, 1)       1
# (8 km, 07/2022, 1)             1
# (25,485 km, 01/2020, 1)        1
# (119,221 km, 08/2013, 1)       1
# (13,575 km, 07/2019, 1)        1
# (241,000 km, 08/1986, 2)       1
# (128,000 km, 06/1989, 4)       1
# (246,484 km, 06/1997, 2)       1
# (134,000 km, 06/1990, 1)       1
# (35,900 km, 06/2020, 1)        1
# (129,732 km, 06/2012, 2)       1
# (89,123 km, 03/2010, 2)        1
# (29,170 km, 10/2018, 1)        1
# (45,700 km, 05/1991, 1)        1
# (50,000 km, 08/2020, 1)        1
# (97,576 km, 06/2012, 1)        1
# (28,000 km, 09/2020, 1)        1
# (33,650 km, 02/2013, 1)        1
# (7,388 km, 06/2021, 1)         1
# (23,500 km, 04/2012, 1)        1
# (6,824 km, 02/2021, 1)         1
# (37,900 km, 12/2015, 1)        1
# (33,227 km, 09/2019, 1)        1
# (70,753 km, 05/2018, 1)        1
# (30,000 km, 03/2013, 1)        1
# (148,758 km, 01/2014, 2)       1
# (1,980 km, 06/2022, 1)         1
# (38,895 km, 07/2020, 2)        1
# (120,749 km, 07/2018, 1)       1
# (18,073 km, 06/2021, 1)        1
# (90,859 km, 04/2008, 5)        1
# (48,880 km, 07/1991, 2)        1
# (31 km, 07/2022, 1)            1
# (15,647 km, 06/2019, 1)        1
# (1,700 km, 02/2021, 1)         1
# (265,000 km, 01/1992, 2)       1
# (75,900 km, 10/2018, 1)        1
# (38,050 km, 02/2020, 2)        1
# (440 km, 02/2022, 1)           1
# (274,000 km, 05/1996, 1)       1
# (160,000 km, 08/1990, 2)       1
# (1,621 km, 06/2022, 1)         1
# (75,659 km, 07/2012, 4)        1
# (75,000 km, 03/2013, 1)        1
# (15,047 km, 08/2021, 1)        1
# (9,900 km, 03/2020, 2)         1
# (3,310 km, 11/2021, 1)         1
# (24,500 km, 02/2021, 1)        1
# (41,937 km, 04/2017, 1)        1
# (89,300 km, 01/2009, 2)        1
# (152,000 km, 03/1991, 1)       1
# (73,000 km, 11/2011, 1)        1
# (38,000 km, 01/2015, 3)        1
# (300,000 km, 08/1992, 2)       1
# (99,990 km, 05/2011, 1)        1
# (17,644 km, 08/2020, 1)        1
# (84,580 km, 11/2015, 1)        1
# (10,300 km, 05/2020, 1)        1
# (96,400 km, 03/2015, 1)        1
# (232,000 km, 11/1999, 2)       1
# (127,000 km, 12/2013, 1)       1
# (89,000 km, 12/2013, 3)        1
# (60,000 km, 01/1996, 1)        1
# (125,000 km, 04/2014, 1)       1
# (22,000 km, 12/2021, 1)        1
# (53,000 km, 09/2017, 1)        1
# (135,595 km, 11/2014, 2)       1
# (8,647 km, 01/2021, 1)         1
# (200,000 km, 12/1986, 1)       1
# (244,000 km, 07/2013, 2)       1
# (225,000 km, 02/1993, 4)       1
# (166,000 km, 02/2010, 1)       1
# (141,789 km, 06/1971, 2)       1
# (94,202 km, 10/2013, 2)        1
# (344,000 km, 02/2004, 1)       1
# (289,000 km, 09/1999, 1)       1
# (18,951 km, 05/2016, 2)        1
# (24,735 km, 09/2018, 2)        1
# (44,500 km, 08/2017, 1)        1
# (45,000 km, 12/2020, 1)        1
# (10,200 km, 08/2020, 1)        1
# (56,767 km, 11/2016, 1)        1
# (51,000 km, 08/2020, 1)        1
# (48,235 km, 02/2020, 1)        1
# (260,000 km, 04/1990, 2)       1
# (150,541 km, 05/2017, 1)       1
# ...
# (7,000 km, 09/2020, 1)         1
# (7,900 km, 02/2021, 1)         1
# (21,830 km, 08/2020, 1)        1
# (13,305 km, 02/2021, 1)        1
# (80,600 km, 11/2006, 2)        1
# (69,380 km, 03/2017, 1)        1
# (105,715 km, 01/2010, 4)       1
# (88,000 km, 09/2017, 1)        1
# (30,490 km, 08/2020, 1)        1
# (20,715 km, 09/2020, 2)        1
# (429 km, 01/2022, 1)           1
# (26,830 km, 09/2020, 1)        1
# (20,340 km, 06/2021, 1)        1
# (128,000 km, 01/2012, 2)       1
# (62,000 km, 08/2011, 1)        1
# (14,355 km, 11/2020, 1)        1
# (63,377 km, 07/2019, 1)        1
# (7,371 km, 02/2021, 1)         1
# (97,000 km, 04/2011, 2)        1
# (28,900 km, 01/2019, 2)        1
# (56,410 km, 03/2014, 1)        1
# (13,508 km, 11/2019, 1)        1
# (4,122 km, 08/2019, 1)         1
# (46,400 km, 09/2020, 1)        1
# (4,567 km, 04/2022, 1)         1
# (50,254 km, 10/2018, 1)        1
# (42,275 km, 02/2021, 2)        1
# (8,900 km, 01/2022, 1)         1
# (9,990 km, 09/2021, 1)         1
# (121,000 km, 06/2008, 3)       1
# (81,373 km, 12/2016, 1)        1
# (48,997 km, 08/2019, 1)        1
# (4,785 km, 08/2020, 1)         1
# (28,097 km, 12/2020, 1)        1
# (9,999 km, 03/2022, 1)         1
# (1,990 km, 08/2022, 1)         1
# (5,660 km, 02/2022, 1)         1
# (60,000 km, 08/2020, 1)        1
# (20,988 km, 08/2020, 1)        1
# (102,912 km, 04/2017, 2)       1
# (13,450 km, 08/2020, 1)        1
# (50,488 km, 11/2018, 1)        1
# (7,877 km, 10/2021, 1)         1
# (74,000 km, 03/2018, 1)        1
# (60,700 km, 06/2019, 1)        1
# (210,000 km, 02/2013, 1)       1
# (37,200 km, 02/2020, 1)        1
# (16,141 km, 01/2022, 1)        1
# (67,794 km, 12/2020, 1)        1
# (321,988 km, 03/2005, 5)       1
# (132,242 km, 04/2015, 1)       1
# (80,892 km, 10/2018, 1)        1
# (42,700 km, 05/2021, 1)        1
# (171,546 km, 02/2007, 2)       1
# (14,091 km, 02/2019, 1)        1
# (104,398 km, 06/2017, 1)       1
# (94,150 km, 04/2016, 2)        1
# (92,780 km, 07/2018, 1)        1
# (144,461 km, 10/2015, 2)       1
# (61,000 km, 02/2015, 1)        1
# (140,809 km, 12/2015, 1)       1
# (26,000 km, 11/2018, 1)        1
# (114,000 km, 02/2017, 1)       1
# (204,000 km, 02/2011, 2)       1
# (81,500 km, 02/2012, 1)        1
# (36,000 km, 05/2019, 2)        1
# (35,880 km, 07/2019, 1)        1
# (53,935 km, 12/2016, 1)        1
# (8,907 km, 02/2022, 1)         1
# (32,606 km, 10/2020, 1)        1
# (25,000 km, 05/2019, 2)        1
# (72,100 km, 12/2017, 2)        1
# (46,388 km, 07/2017, 1)        1
# (141,000 km, 11/2014, 2)       1
# (38,500 km, 12/2018, 1)        1
# (88,590 km, 03/2016, 4)        1
# (46,503 km, 12/2019, 1)        1
# (60,500 km, 03/2018, 1)        1
# (5,654 km, 10/2021, 1)         1
# (220,000 km, 04/2012, 1)       1
# (9,000 km, 05/2021, 1)         1
# (98,997 km, 07/2018, 2)        1
# (223,889 km, 09/2013, 2)       1
# (108,900 km, 06/2017, 1)       1
# (127,390 km, 11/2012, 2)       1
# (39,650 km, 07/2020, 1)        1
# (191,000 km, 02/2011, 1)       1
# (138,531 km, 10/2015, 1)       1
# (47,000 km, 06/2015, 1)        1
# (51,028 km, 02/2019, 2)        1
# (28,500 km, 06/2018, 1)        1
# (117,767 km, 04/2010, 1)       1
# (145,000 km, 01/2017, 1)       1
# (330,000 km, 12/2011, 1)       1
# (66,000 km, 04/2019, 1)        1
# (47,777 km, 05/2019, 1)        1
# (97,900 km, 04/2018, 1)        1
# (29,600 km, 08/2020, 1)        1
# (56,290 km, 06/2021, 1)        1
# (118,049 km, 04/2018, 1)       1
# (51,961 km, 02/2019, 2)        1
# (7,890 km, 06/2022, 1)         1
# (76,168 km, 04/2018, 1)        1
# (129,707 km, 02/2018, 1)       1
# (109,554 km, 01/2016, 2)       1
# (30,900 km, 06/2019, 1)        1
# (51,385 km, 01/2020, 1)        1
# (58,800 km, 12/2018, 3)        1
# (84,687 km, 09/2018, 1)        1
# (32,781 km, 02/2020, 1)        1
# (78,000 km, 10/2016, 1)        1
# (31,694 km, 02/2019, 1)        1
# (154,789 km, 11/2017, 1)       1
# (88,000 km, 03/2017, 1)        1
# (23,560 km, 02/2021, 1)        1
# (53,625 km, 11/2018, 1)        1
# (79,809 km, 01/2017, 2)        1
# (54,799 km, 02/2021, 1)        1
# (46,088 km, 04/2017, 1)        1
# (156,171 km, 05/2013, 2)       1
# (26,000 km, 07/2020, 1)        1
# (55,445 km, 05/2018, 1)        1
# (153,213 km, 09/2018, 2)       1
# (77,857 km, 02/2018, 1)        1
# (42,118 km, 05/2019, 1)        1
# (138,669 km, 03/2018, 3)       1
# (82,869 km, 06/2020, 1)        1
# (76,264 km, 07/2019, 1)        1
# (132,415 km, 05/2009, 2)       1
# (220,148 km, 01/2003, 2)       1
# (114,000 km, 04/2012, 2)       1
# (4,281 km, 04/2022, 2)         1
# (201,000 km, 10/2002, 4)       1
# (64,800 km, 06/2010, 1)        1
# (89,000 km, 09/2002, 2)        1
# (85,292 km, 10/2011, 1)        1
# (65,251 km, 06/2011, 2)        1
# (240,171 km, 05/2013, 1)       1
# (173,000 km, 05/2013, 2)       1
# (170,030 km, 07/2004, 2)       1
# (178,000 km, 04/2003, 5)       1
# (132,500 km, 06/2011, 2)       1
# (104,000 km, 01/2011, 1)       1
# (165,000 km, 04/2004, 3)       1
# (225,339 km, 06/2001, 8)       1
# (190,200 km, 05/2012, 2)       1
# (219,000 km, 05/2008, 1)       1
# (223,000 km, 07/2011, 2)       1
# (184,014 km, 04/2009, 1)       1
# (208,000 km, 09/2001, 3)       1
# (71,000 km, 05/2005, 1)        1
# (124,935 km, 02/2013, 1)       1
# (114,000 km, 02/2012, 3)       1
# (79,000 km, 04/2006, 1)        1
# (86,000 km, 03/2010, 1)        1
# (49,785 km, 11/2011, 2)        1
# (71,500 km, 01/2002, 1)        1
# (170,000 km, 06/2005, 1)       1
# (87,000 km, 04/2014, 2)        1
# (241,229 km, 02/2003, 4)       1
# (156,007 km, 09/2006, 4)       1
# (36,200 km, 06/2011, 2)        1
# (107,800 km, 09/2003, 3)       1
# (122,000 km, 06/2009, 1)       1
# (148,000 km, 05/1999, 3)       1
# (41,400 km, 08/2014, 1)        1
# (145,654 km, 01/2006, 2)       1
# (87,000 km, 02/2007, 3)        1
# (142,000 km, 06/2010, 2)       1
# (57,000 km, 03/2013, 2)        1
# (139,445 km, 09/2007, 5)       1
# (9,063 km, 05/2010, 1)         1
# (203,837 km, 07/2003, 2)       1
# (126,000 km, 03/2004, 1)       1
# (111,777 km, 03/2004, 2)       1
# (227,000 km, 07/2001, 2)       1
# (167,235 km, 04/2006, 4)       1
# (189,241 km, 01/2003, 4)       1
# (104,408 km, 08/2003, 3)       1
# (78,000 km, 08/2009, 1)        1
# (176,000 km, 03/2004, 5)       1
# (155,000 km, 10/2001, 3)       1
# (128,646 km, 05/1997, 13)      1
# (72,186 km, 05/2014, 2)        1
# (149,879 km, 10/2010, 2)       1
# (255,100 km, 09/2003, 3)       1
# (174,000 km, 11/2011, 2)       1
# (96,000 km, 11/2011, 1)        1
# (188,000 km, 03/2002, 3)       1
# (221,183 km, 07/2003, 2)       1
# (206,263 km, 12/2007, 5)       1
# (202,171 km, 04/2001, 5)       1
# (34,276 km, 04/2005, 2)        1
# (100,000 km, 07/2008, 2)       1
# (111,600 km, 02/2006, 1)       1
# (213,879 km, 06/2005, 3)       1
# (72,195 km, 05/2014, 1)        1
# (80,000 km, 02/2000, 2)        1
# (163,000 km, 06/2012, 1)       1
# (195,094 km, 07/2007, 2)       1
# (182,688 km, 03/2001, 4)       1
# (115,349 km, 02/2013, 2)       1
# (148,000 km, 02/2002, 3)       1
# (108,000 km, 06/2011, 2)       1
# (123,000 km, 03/2009, 2)       1
# (166,000 km, 11/2009, 3)       1
# (144,500 km, 05/1989, 1)       1
# (84,500 km, 07/2013, 2)        1
# (150,000 km, 07/2004, 3)       1
# (223,737 km, 01/2003, 6)       1
# (210,000 km, 06/2005, 3)       1
# (177,000 km, 11/2004, 2)       1
# (167,500 km, 06/2007, 2)       1
# (211,467 km, 08/2005, 3)       1
# (180,000 km, 05/2007, 1)       1
# (84,000 km, 01/2013, 2)        1
# (196,700 km, 08/2002, 3)       1
# (141,000 km, 08/2005, 1)       1
# (93,135 km, 06/2006, 2)        1
# (121,345 km, 05/2007, 1)       1
# (25,500 km, 12/2020, 3)        1
# (27,888 km, 04/2020, 1)        1
# (138,355 km, 06/2007, 3)       1
# (35,074 km, 11/2018, 1)        1
# (81,775 km, 03/2019, 1)        1
# (49,054 km, 10/2016, 1)        1
# (13,622 km, 12/2020, 1)        1
# (59,520 km, 06/2015, 2)        1
# (168,562 km, 01/2010, 7)       1
# (76,795 km, 04/2013, 1)        1
# (10,250 km, 02/2020, 1)        1
# (59,592 km, 11/2017, 1)        1
# (2,095 km, 09/2020, 1)         1
# (14,987 km, 10/2018, 1)        1
# (51,851 km, 02/2019, 5)        1
# (1,110 km, 01/2022, 1)         1
# (94,730 km, 09/2008, 2)        1
# (31,103 km, 10/2019, 1)        1
# (67,505 km, 11/2013, 2)        1
# (65,559 km, 10/2018, 2)        1
# (3,740 km, 10/2019, 1)         1
# (90,092 km, 09/2015, 3)        1
# (14,395 km, 09/2020, 1)        1
# (45,878 km, 06/2014, 3)        1
# (114,281 km, 09/2014, 5)       1
# (68,442 km, 10/2019, 3)        1
# (21,066 km, 09/2019, 1)        1
# (8,649 km, 10/2021, 1)         1
# (28,947 km, 09/2020, 1)        1
# (30,482 km, 08/2013, 1)        1
# (55,099 km, 06/2014, 2)        1
# (106,297 km, 04/2013, 3)       1
# (56,255 km, 02/2019, 1)        1
# (43,478 km, 12/2017, 3)        1
# (23,506 km, 02/2019, 1)        1
# (13,509 km, 03/2022, 1)        1
# (23,061 km, 04/2020, 2)        1
# (58,630 km, 10/2007, 3)        1
# (13,017 km, 02/2021, 2)        1
# (6,700 km, 01/2021, 1)         1
# (41,591 km, 11/2018, 1)        1
# (11,802 km, 11/2017, 1)        1
# (36,025 km, 02/2017, 1)        1
# (112,446 km, 05/2015, 1)       1
# (13,956 km, 07/2020, 1)        1
# (56,000 km, 04/2008, 2)        1
# (82,000 km, 07/2010, 2)        1
# (61,430 km, 07/2014, 1)        1
# (318,441 km, 08/2007, 7)       1
# (105,840 km, 06/2010, 3)       1
# (196,288 km, 05/2011, 3)       1
# (106,750 km, 05/2009, 2)       1
# (177,148 km, 06/2006, 2)       1
# (41,168 km, 10/2012, 1)        1
# (143,350 km, 04/2011, 2)       1
# (190,000 km, 11/2010, 1)       1
# (230,083 km, 08/2008, 1)       1
# (142,443 km, 01/2012, 1)       1
# (52,500 km, 04/2011, 3)        1
# (73,364 km, 06/2010, 1)        1
# (45,188 km, 05/1990, 1)        1
# (16,000 km, 07/2021, 1)        1
# (102,000 km, 03/2006, 1)       1
# (76,200 km, 11/2012, 2)        1
# (169,998 km, 08/2010, 2)       1
# (188,790 km, 10/2007, 14)      1
# (48,808 km, 08/2016, 5)        1
# (107,000 km, 05/2011, 2)       1
# (69,168 km, 01/2018, 4)        1
# (63,263 km, 04/2013, 2)        1
# (29,148 km, 12/2019, 1)        1
# (46,001 km, 02/2019, 2)        1
# (83,214 km, 06/2013, 1)        1
# (42,650 km, 06/2015, 2)        1
# (88,505 km, 08/2010, 1)        1
# (92,037 km, 07/2011, 1)        1
# (62,325 km, 05/2015, 4)        1
# (150,800 km, 01/2004, 7)       1
# (79,152 km, 10/2012, 2)        1
# (68,779 km, 11/2012, 1)        1
# (117,000 km, 06/2008, 3)       1
# (26,401 km, 03/2018, 2)        1
# (119,158 km, 02/2002, 3)       1
# (12,499 km, 09/2020, 1)        1
# (119,000 km, 12/2004, 2)       1
# (35,900 km, 09/2010, 1)        1
# (190,000 km, 08/2010, 1)       1
# (212,159 km, 01/2007, 2)       1
# (74,520 km, 09/2010, 2)        1
# (195,000 km, 07/2010, 2)       1
# (110,535 km, 09/2011, 2)       1
# (27,000 km, 02/2006, 1)        1
# (245,579 km, 06/2006, 3)       1
# (173,620 km, 05/2012, 3)       1
# (143,000 km, 04/2010, 2)       1
# (24,624 km, 04/2013, 1)        1
# (80,961 km, 11/2011, 4)        1
# (155,000 km, 08/2011, 1)       1
# (97,900 km, 03/2011, 1)        1
# (180,000 km, 11/2007, 3)       1
# (103,159 km, 10/2007, 1)       1
# (123,000 km, 08/2004, 3)       1
# (258,000 km, 05/1994, 2)       1
# (45,800 km, 03/2012, 2)        1
# (134,600 km, 09/2013, 4)       1
# (196,579 km, 08/2011, 2)       1
# (27,600 km, 04/2010, 2)        1
# (52,000 km, 03/2012, 2)        1
# (70,000 km, 03/2012, 1)        1
# (133,000 km, 01/1990, 2)       1
# (82,349 km, 11/2015, 2)        1
# (30,300 km, 11/2018, 1)        1
# (172,000 km, 04/2014, 1)       1
# (170,605 km, 01/1992, 3)       1
# (145,000 km, 02/2013, 3)       1
# (97,733 km, 03/2015, 1)        1
# (175,652 km, 07/2011, 5)       1
# (166,100 km, 11/2012, 2)       1
# (74,000 km, 08/2013, 2)        1
# (143,000 km, 03/2015, 2)       1
# (216,000 km, 05/1987, 3)       1
# (177,000 km, 11/2011, 1)       1
# (165,000 km, 09/1997, 1)       1
# (80,000 km, 12/2013, 2)        1
# (153,000 km, 01/2012, 2)       1
# (95,380 km, 03/2015, 3)        1
# (84,771 km, 02/2013, 2)        1
# (209,178 km, 12/2005, 8)       1
# (93,200 km, 07/2015, 1)        1
# (34,800 km, 03/2014, 1)        1
# (77,700 km, 07/2013, 5)        1
# (45,500 km, 05/2012, 2)        1
# (70,000 km, 03/2007, 1)        1
# (249,189 km, 09/2010, 1)       1
# (215,000 km, 12/2009, 1)       1
# (27,598 km, 01/2020, 1)        1
# (242,368 km, 03/2002, 1)       1
# (184,000 km, 04/2007, 1)       1
# (91,000 km, 06/2002, 1)        1
# (43,090 km, 02/2001, 1)        1
# (47,636 km, 11/2013, 1)        1
# (150 km, 11/2013, 1)           1
# (200,800 km, 10/2001, 1)       1
# (89,000 km, 07/2008, 1)        1
# (54,000 km, 07/2011, 2)        1
# (94,218 km, 04/2011, 2)        1
# (192,500 km, 02/2011, 3)       1
# (72,000 km, 04/2013, 1)        1
# (214,670 km, 03/2006, 6)       1
# (181,705 km, 10/2006, 2)       1
# (123,000 km, 06/2006, 1)       1
# (80,300 km, 01/2013, 2)        1
# (159,000 km, 04/2008, 2)       1
# (53,659 km, 05/2012, 2)        1
# (165,000 km, 02/2015, 1)       1
# (56,000 km, 12/2006, 1)        1
# (136,131 km, 11/2001, 1)       1
# (127,000 km, 02/2006, 2)       1
# (131,000 km, 05/2015, 1)       1
# (127,000 km, 11/2010, 1)       1
# (114,000 km, 04/2015, 2)       1
# (52,050 km, 03/2016, 1)        1
# (90,000 km, 03/2012, 3)        1
# (82,573 km, 09/2017, 1)        1
# (154,000 km, 05/2008, 2)       1
# (79,400 km, 03/2014, 1)        1
# (114,600 km, 06/2011, 3)       1
# (45,678 km, 09/2010, 1)        1
# (120,000 km, 04/2011, 1)       1
# (152,544 km, 01/2012, 1)       1
# (75,100 km, 02/2012, 3)        1
# (152,000 km, 05/2012, 1)       1
# (3,000 km, 01/2011, 2)         1
# (60,000 km, 11/2011, 2)        1
# (130,000 km, 04/2007, 1)       1
# (175,351 km, 09/2012, 1)       1
# (160,750 km, 09/2011, 3)       1
# (75,306 km, 03/2015, 1)        1
# (60,000 km, 11/2013, 1)        1
# (105,733 km, 10/2015, 1)       1
# (115,000 km, 05/2006, 1)       1
# (62,500 km, 06/1991, 3)        1
# (83,000 km, 03/2011, 2)        1
# (166,000 km, 07/2011, 1)       1
# (125,000 km, 04/2011, 1)       1
# (189,000 km, 11/1978, 4)       1
# (147,215 km, 03/2011, 2)       1
# (101,918 km, 03/2012, 3)       1
# (156,517 km, 06/2012, 1)       1
# (109,500 km, 03/2014, 2)       1
# (87,500 km, 04/2013, 2)        1
# (116,000 km, 12/2010, 1)       1
# (43,000 km, 12/2011, 1)        1
# (145,900 km, 11/2011, 2)       1
# (139,000 km, 03/2006, 1)       1
# (173,000 km, 05/2015, 3)       1
# (163,242 km, 03/2008, 2)       1
# (64,863 km, 05/2015, 2)        1
# (117,103 km, 04/2013, 1)       1
# (175,539 km, 06/2011, 2)       1
# (206,000 km, 11/2007, 2)       1
# (89,000 km, 09/2006, 1)        1
# (107,000 km, 07/2010, 1)       1
# (150,230 km, 03/2003, 2)       1
# (66,554 km, 04/2003, 1)        1
# (107,000 km, 04/2014, 2)       1
# (87,916 km, 03/2003, 2)        1
# (129,436 km, 04/2004, 3)       1
# (82,908 km, 08/2011, 3)        1
# (137,000 km, 04/2001, 1)       1
# (173,000 km, 02/2010, 1)       1
# (64,500 km, 08/2011, 1)        1
# (125,000 km, 03/2004, 2)       1
# (247,568 km, 06/2012, 1)       1
# (108,000 km, 07/1999, 2)       1
# (65,000 km, 08/2001, 1)        1
# (126,000 km, 02/2004, 3)       1
# (170,000 km, 08/2006, 2)       1
# (136,000 km, 08/1990, 1)       1
# (140,000 km, 03/2014, 2)       1
# (24,298 km, 06/2013, 2)        1
# (88,632 km, 05/2014, 2)        1
# (177,783 km, 04/2008, 2)       1
# (141,808 km, 03/2000, 3)       1
# (93,000 km, 09/2010, 3)        1
# (24,000 km, 11/2012, 1)        1
# (96,200 km, 08/2012, 4)        1
# (145,000 km, 03/1987, 3)       1
# (115,300 km, 03/2011, 1)       1
# (86,978 km, 01/2014, 2)        1
# (154,028 km, 07/2011, 2)       1
# (121,500 km, 02/2013, 4)       1
# (131,270 km, 08/2010, 2)       1
# (65,000 km, 10/2008, 1)        1
# (68,822 km, 08/2013, 1)        1
# (208,000 km, 02/2007, 3)       1
# (137,700 km, 01/2011, 3)       1
# (255,100 km, 04/2009, 2)       1
# (143,000 km, 04/2011, 1)       1
# (43,000 km, 09/1997, 1)        1
# (83,281 km, 06/2011, 1)        1
# (163,000 km, 06/2010, 2)       1
# (140,000 km, 05/2006, 3)       1
# (136,000 km, 02/2011, 2)       1
# (140,659 km, 08/2015, 4)       1
# (100,000 km, 01/2007, 2)       1
# (170,000 km, 04/2006, 2)       1
# (149,000 km, 07/2013, 3)       1
# (55,000 km, 09/2014, 1)        1
# (156,000 km, 01/2014, 2)       1
# (29,900 km, 12/2016, 1)        1
# (126,720 km, 01/2014, 6)       1
# (150,627 km, 09/2009, 2)       1
# (130,288 km, 04/2011, 2)       1
# (79,585 km, 05/2012, 1)        1
# (165,000 km, 12/2010, 1)       1
# (257,500 km, 05/2010, 2)       1
# (10,000 km, 06/1992, 1)        1
# (358,000 km, 10/2010, 2)       1
# (165,400 km, 09/2010, 1)       1
# (65,000 km, 10/2006, 1)        1
# (71,000 km, 04/2013, 1)        1
# (134,000 km, 11/2006, 1)       1
# (230,047 km, 07/2002, 5)       1
# Name: count, dtype: int64

# %%
# Task 10 previous_owner
def extract_user_count(val):
    # Eğer NaN ise None döndür
    if pd.isna(val):
        return 0
    
    # Eğer tuple ise son elemanı al
    if isinstance(val, tuple) or isinstance(val, list):
        try:
            return int(val[-1])
        except:
            return 0
    
    # Eğer string ise
    if isinstance(val, str):
        try:
            # Parantezleri temizle, ardından son virgülden sonrası alınır
            val_clean = val.strip("() ")
            parts = val_clean.split(",")
            return int(parts[-1].strip())
        except:
            return 0
    
    # Diğer durumlarda None
    return 0

# %%
ri1['previous_owner'] = ri1['previous_owner'].apply(extract_user_count)

# %%
ri1["previous_owner"].value_counts(dropna=False)
# Out:
# previous_owner
# 0     14615
# 1      9746
# 2      3221
# 3       699
# 4       184
# 5        69
# 6        37
# 7        22
# 8        16
# 9        14
# 12        3
# 10        2
# 14        1
# 13        1
# Name: count, dtype: int64

# %%
def clean_co2_emissions_column(df, column_name):
    """
    'g/km (comb.)' gibi metinli CO2 verilerini temizleyip sadece sayısal değeri float olarak bırakır.
    Orijinal sütun inplace olarak güncellenir.
    
    Örn: "119 g/km (comb.)" → 119.0
    """
    df[column_name] = (
        df[column_name]
          .astype(str)
          .str.extract(r'(\d+\.?\d*)')[0]   # Sayı kısmını çek
          .astype(float)                   # Float'a çevir
    )

# %%
clean_co2_emissions_column(ri1, 'CO2_emissions')

# %%
ri1.CO2_emissions.value_counts(dropna=False)
# Out:
# CO2_emissions
# NaN      10036
# 0.0       1040
# 119.0      393
# 124.0      340
# 129.0      319
# 114.0      313
# 99.0       312
# 115.0      304
# 139.0      299
# 109.0      265
# 108.0      262
# 125.0      255
# 149.0      255
# 130.0      230
# 123.0      230
# 138.0      230
# 120.0      218
# 117.0      214
# 110.0      213
# 127.0      211
# 126.0      204
# 111.0      204
# 104.0      197
# 112.0      186
# 95.0       184
# 107.0      179
# 135.0      178
# 116.0      175
# 154.0      173
# 134.0      171
# 145.0      170
# 122.0      170
# 133.0      165
# 178.0      165
# 113.0      161
# 128.0      159
# 106.0      158
# 121.0      157
# 103.0      157
# 131.0      153
# 93.0       147
# 98.0       144
# 105.0      142
# 156.0      141
# 118.0      139
# 140.0      139
# 148.0      139
# 155.0      137
# 159.0      136
# 88.0       136
# 136.0      135
# 144.0      135
# 102.0      134
# 96.0       133
# 147.0      127
# 158.0      127
# 161.0      125
# 94.0       118
# 92.0       117
# 142.0      117
# 167.0      114
# 132.0      114
# 137.0      112
# 143.0      109
# 166.0      107
# 169.0      106
# 146.0      103
# 164.0      102
# 101.0      100
# 152.0       97
# 174.0       92
# 85.0        92
# 97.0        91
# 151.0       88
# 153.0       87
# 171.0       86
# 150.0       84
# 89.0        82
# 191.0       81
# 170.0       77
# 165.0       76
# 162.0       73
# 168.0       72
# 175.0       71
# 180.0       70
# 196.0       70
# 194.0       68
# 157.0       68
# 90.0        67
# 177.0       67
# 141.0       66
# 273.0       65
# 185.0       65
# 218.0       64
# 230.0       62
# 160.0       62
# 179.0       61
# 193.0       60
# 163.0       60
# 184.0       57
# 190.0       57
# 173.0       56
# 195.0       56
# 82.0        56
# 181.0       56
# 229.0       55
# 199.0       50
# 176.0       50
# 100.0       48
# 219.0       47
# 212.0       46
# 34.0        45
# 42.0        44
# 200.0       43
# 209.0       42
# 225.0       41
# 261.0       41
# 183.0       40
# 41.0        39
# 248.0       38
# 197.0       38
# 226.0       38
# 192.0       38
# 26.0        37
# 187.0       35
# 189.0       35
# 234.0       34
# 182.0       33
# 49.0        33
# 76.0        33
# 275.0       33
# 289.0       32
# 210.0       32
# 263.0       32
# 253.0       31
# 215.0       30
# 186.0       30
# 64.0        30
# 284.0       30
# 38.0        30
# 268.0       30
# 188.0       29
# 84.0        29
# 242.0       28
# 220.0       28
# 172.0       28
# 47.0        27
# 40.0        27
# 214.0       26
# 39.0        25
# 86.0        25
# 280.0       25
# 87.0        25
# 211.0       24
# 79.0        24
# 279.0       24
# 91.0        23
# 245.0       22
# 254.0       22
# 288.0       22
# 75.0        22
# 36.0        21
# 217.0       21
# 35.0        21
# 205.0       21
# 236.0       20
# 270.0       20
# 216.0       19
# 208.0       19
# 202.0       19
# 31.0        18
# 232.0       18
# 48.0        18
# 1.0         18
# 201.0       17
# 262.0       16
# 299.0       16
# 235.0       16
# 32.0        16
# 204.0       16
# 252.0       16
# 198.0       16
# 259.0       15
# 203.0       15
# 246.0       15
# 278.0       15
# 46.0        15
# 223.0       14
# 54.0        14
# 213.0       14
# 250.0       14
# 83.0        14
# 50.0        14
# 25.0        13
# 207.0       13
# 221.0       13
# 238.0       13
# 206.0       13
# 244.0       12
# 247.0       12
# 285.0       12
# 44.0        11
# 256.0       11
# 277.0       11
# 281.0       11
# 258.0       11
# 231.0       10
# 222.0       10
# 51.0        10
# 240.0       10
# 78.0        10
# 224.0       10
# 298.0       10
# 295.0       10
# 37.0         9
# 311.0        9
# 260.0        9
# 33.0         9
# 249.0        9
# 228.0        9
# 237.0        8
# 287.0        8
# 251.0        8
# 267.0        8
# 29.0         8
# 292.0        8
# 282.0        8
# 52.0         8
# 239.0        8
# 28.0         8
# 59.0         8
# 255.0        8
# 265.0        7
# 55.0         6
# 330.0        6
# 312.0        6
# 257.0        6
# 306.0        6
# 296.0        6
# 14.0         5
# 22.0         5
# 30.0         5
# 66.0         5
# 327.0        5
# 269.0        5
# 68.0         5
# 227.0        5
# 43.0         5
# 283.0        5
# 303.0        4
# 320.0        4
# 81.0         4
# 27.0         4
# 243.0        4
# 24.0         4
# 276.0        4
# 274.0        4
# 241.0        4
# 322.0        4
# 271.0        4
# 18.0         3
# 15.0         3
# 300.0        3
# 319.0        3
# 310.0        3
# 324.0        3
# 17.0         3
# 8.0          2
# 414.0        2
# 290.0        2
# 336.0        2
# 16.0         2
# 340.0        2
# 45.0         2
# 23.0         2
# 233.0        2
# 293.0        2
# 264.0        2
# 400.0        2
# 56.0         2
# 10.0         2
# 65.0         2
# 272.0        1
# 9.0          1
# 71.0         1
# 307.0        1
# 326.0        1
# 313.0        1
# 399.0        1
# 940.0        1
# 294.0        1
# 420.0        1
# 328.0        1
# 304.0        1
# 314.0        1
# 350.0        1
# 339.0        1
# 394.0        1
# 910.0        1
# 343.0        1
# 316.0        1
# 341.0        1
# 21.0         1
# 317.0        1
# 335.0        1
# 20.0         1
# 19.0         1
# 345.0        1
# 13.0         1
# 348.0        1
# 266.0        1
# 373.0        1
# 344.0        1
# 80.0         1
# 398.0        1
# 7.0          1
# 377.0        1
# 5.0          1
# 3.0          1
# 308.0        1
# 321.0        1
# 73.0         1
# 332.0        1
# 70.0         1
# 338.0        1
# 342.0        1
# 53.0         1
# Name: count, dtype: int64

# %%
#ri2["electric_range_wltp"].value_counts(dropna=False) 28614 NaN value

# %%
ri16=ri1.copy()

# %%
def map_fuel_type(fuel):
    # Check if it's not a string or it's empty
    if not isinstance(fuel, str) or fuel.strip() == '':
        return 'nan Value'
    f = fuel.lower()
    if 'others' in f:
        value= 'Others'
    if 'electric' in f:
        value='Electric'
    if 'diesel' in f:
        value = 'Diesel'
    # Petrol keywords
    if any(kw in f for kw in ['gasoline', 'super', 'benzine', 'regular']):
        value ='Petrol' 
    if any(kw in f for kw in ['cng', 'domestic gas','liquid petroleum gas','biogas', 'lpg','hydrogen', 'ethanol']):
        value = 'Gas'
    return value

# %%
ri16['fuel_type_new'] = ri1['fuel_type'].apply(map_fuel_type)

# %%
ri16['fuel_type_new'].value_counts()
# Out:
# fuel_type_new
# Petrol       17330
# Diesel        8727
# nan Value     1787
# Gas            385
# Others         213
# Electric       188
# Name: count, dtype: int64

# %%
#ri16.head()

# %%
################## energy_efficiency

# %%
#For vehicles to be classified in categories A and B, they must achieve or fall below the valid CO2 target values.
#Bu sebeple Ave B iicn 1 digerleri ve NaN icin 0 ile degisiklik yapilmistir.

# %%
def classify_efficiency(value):
    if isinstance(value, str):
        value_upper = value.upper()
        if 'A' in value_upper or 'B' in value_upper:
            return 1
    return 0

# %%
ri16['energy_efficient'] = ri16['energy_efficiency_class'].apply(classify_efficiency)

# %%
ri16.energy_efficient.value_counts(dropna=False)
# Out:
# energy_efficient
# 0    23322
# 1     5308
# Name: count, dtype: int64

# %%
##################

# %%
############fuel_consumption column: 3 ayri sutun olusturma ve decimal degerleri alarak cleaning

# %%
import ast

# %%
# String olarak görünen tuple verileri güvenli biçimde dönüştür
def parse_fuel_string(value):
    if isinstance(value, str) and value.startswith("("):
        try:
            return ast.literal_eval(value)
        except (ValueError, SyntaxError):
            return None
    return value

# %%
#fuel_consumption sütununu tuple olarak parse et
ri16['fuel_consumption'] = ri16['fuel_consumption'].apply(parse_fuel_string)

# %%
# Ondalık sayıyı string içinden çeken fonksiyon
def extract_first_decimal(text):
    if not isinstance(text, str):
        return text
    match = re.search(r'\d+\.\d+', text.replace(',', '.'))
    return float(match.group()) if match else np.nan

# %%
# Tuple verisini yakıt türlerine göre doğru kolonlara ayır
def split_fuel_values(value):
    result = {'fuel_comb': None, 'fuel_city': None, 'fuel_country': None}
    if isinstance(value, (list, tuple)):
        for item in value:
            if isinstance(item, str):
                if 'comb.' in item:
                    result['fuel_comb'] = extract_first_decimal(item)
                    
                elif 'city' in item:
                    result['fuel_city'] = extract_first_decimal(item)
                elif 'country' in item:
                    result['fuel_country'] = extract_first_decimal(item)
    return pd.Series(result)

# %%
# Decimal değerleri fuel_comb, fuel_city, fuel_country olarak ayır
ri16[['fuel_comb', 'fuel_city', 'fuel_country']] = ri16['fuel_consumption'].apply(split_fuel_values)

# %%
##################### cleaning:'power_consumption','electric_range_wltp', 'power_consumption_wltp', 'fuel_consumption_wltp'

# %%
columns_for_decimal_cleaning=['power_consumption','electric_range_wltp', 'power_consumption_wltp', 'fuel_consumption_wltp']

# %%
ri16[columns_for_decimal_cleaning]=ri1[columns_for_decimal_cleaning]

# %%
ri16[columns_for_decimal_cleaning]=ri16[columns_for_decimal_cleaning].applymap(extract_first_decimal)

# %%
extract_first_decimal('15.7 kWh/100 km (comb.)')
# Out:
# 15.7

# %%
for i in columns_for_decimal_cleaning:
    print(ri16[i].value_counts(dropna=False))
# Out:
# power_consumption
# NaN     28267
# 15.2       30
# 15.7       19
# 17.7       17
# 15.9       14
# 18.1       13
# 15.8       11
# 16.8       11
# 14.9       11
# 16.1        9
# 20.5        9
# 18.7        9
# 16.9        8
# 16.3        8
# 17.3        8
# 14.7        7
# 16.5        6
# 17.8        6
# 17.5        6
# 14.8        6
# 3.4         5
# 99.9        5
# 17.2        5
# 13.9        5
# 15.5        4
# 15.6        4
# 16.2        4
# 17.6        4
# 16.6        4
# 17.1        4
# 21.9        4
# 3.8         4
# 20.9        4
# 15.3        4
# 16.4        4
# 1.7         4
# 23.8        4
# 22.4        4
# 14.3        3
# 5.2         3
# 19.5        3
# 19.1        3
# 15.4        3
# 19.8        3
# 21.6        3
# 4.3         2
# 17.4        2
# 16.7        2
# 11.5        2
# 14.4        2
# 20.7        2
# 1.2         2
# 18.5        2
# 22.2        2
# 14.6        2
# 1.8         2
# 25.9        2
# 10.6        1
# 21.7        1
# 21.4        1
# 19.3        1
# 9.9         1
# 10.3        1
# 26.3        1
# 13.8        1
# 19.2        1
# 23.2        1
# 25.3        1
# 10.5        1
# 19.9        1
# 3.9         1
# 12.7        1
# 22.7        1
# 18.3        1
# 13.3        1
# 13.4        1
# 20.3        1
# 20.4        1
# 18.4        1
# 4.5         1
# 14.5        1
# 19.6        1
# 18.2        1
# 12.8        1
# 17.9        1
# 11.9        1
# 13.7        1
# 12.9        1
# 0.1         1
# 23.4        1
# 6.3         1
# Name: count, dtype: int64
# electric_range_wltp
# NaN    28630
# Name: count, dtype: int64
# power_consumption_wltp
# NaN     28615
# 21.9        2
# 17.2        2
# 20.6        2
# 18.9        1
# 19.2        1
# 18.4        1
# 19.3        1
# 15.9        1
# 16.9        1
# 18.7        1
# 18.1        1
# 18.6        1
# Name: count, dtype: int64
# fuel_consumption_wltp
# NaN     28542
# 5.5         9
# 5.4         5
# 6.8         5
# 6.5         4
# 7.3         4
# 5.7         4
# 6.7         3
# 4.9         3
# 5.2         3
# 6.6         3
# 5.9         2
# 6.1         2
# 5.6         2
# 6.3         2
# 4.7         2
# 4.4         2
# 5.8         2
# 9.3         2
# 12.6        2
# 6.2         2
# 7.6         2
# 8.4         2
# 8.6         1
# 8.3         1
# 8.2         1
# 5.3         1
# 10.4        1
# 12.9        1
# 9.1         1
# 9.6         1
# 7.2         1
# 4.8         1
# 10.3        1
# 1.5         1
# 4.2         1
# 4.3         1
# 1.1         1
# 12.3        1
# 4.1         1
# 3.9         1
# 6.4         1
# 12.2        1
# 7.8         1
# Name: count, dtype: int64

# %%
##################'comfort_convenience','entertainment_media','safety_security','extras' icin numeric deger olusturma:
### virgulleri sayarak kac adet ozellik icerdigi +1 eklenerek bulunur.Nan degerler ve string olmayan degerler ayni degerin kendisi olarak yazilir

# %%
def count_commas_plus_one(cell):
    if not isinstance(cell, str):
        return cell 
    return cell.count(',') + 1

# %%
column_to_count_commas=['comfort_convenience','entertainment_media','safety_security','extras']

# %%
ri16[['cc_num','em_num','ss_num','extras_num']]=ri16[column_to_count_commas].applymap(count_commas_plus_one)

# %%
ri16.sample(7)
# Out:
#                      make_model  \
# 23450                Ford Focus
# 975    Mercedes-Benz GLE 63 AMG
# 181         Mercedes-Benz A 200
# 9101             Peugeot Rifter
# 26271                 Volvo V40
# 3088                    Opel GT
# 6570             Renault Megane
#
#                                        short_description           make  \
# 23450                       1.0 EcoBoost Hybrid TITANIUM           Ford
# 975                                  Coupé S 4Matic Aut.  Mercedes-Benz
# 181                                          200d 7G-DCT  Mercedes-Benz
# 9101   1.2 PURETECH 130CH S\u0026S STANDARD EAT8 ATTE...        Peugeot
# 26271                                     D2 Kinetic 120          Volvo
# 3088                        2.0 Turbo Cabriolet 92.000Km           Opel
# 6570               Megane SporTour 1.5 dci Limited 110cv        Renault
#
#             model location    price      body_type  type doors  \
# 23450       Focus       DE  23790.0          Sedan  Used     5
# 975    GLE 63 AMG       ES  75490.0          Coupe  Used     5
# 181         A 200       ES  19990.0        Compact  Used     5
# 9101       Rifter       FR  29450.0  Station wagon  Used     5
# 26271         V40       ES  13818.0        Compact  Used     5
# 3088           GT       BE  16950.0    Convertible  Used     2
# 6570       Megane       IT  10904.0  Station wagon  Used     5
#
#       country_version offer_number  warranty   mileage first_registration  \
# 23450         Germany  920057_7195       NaN    1400.0         2021-02-01
# 975             Spain      7214850      12.0   49000.0         2017-03-01
# 181             Spain      7282398      12.0   87119.0         2017-03-01
# 9101              NaN          462       NaN   16850.0         2020-12-01
# 26271           Spain      7328025      12.0  145040.0         2018-03-01
# 3088          Belgium          NaN      12.0   92000.0         2009-03-01
# 6570              NaN      6153005       0.0  144500.0         2015-07-01
#
#          gearbox                   fuel_type colour     paint  \
# 23450     Manual  Super 95 (Particle filter)   Blue  Metallic
# 975    Automatic                    Gasoline  White  Metallic
# 181    Automatic                      Diesel  White       NaN
# 9101   Automatic                    Gasoline    NaN       NaN
# 26271     Manual                      Diesel  White       NaN
# 3088      Manual                    Gasoline  Black  Metallic
# 6570      Manual                      Diesel  White       NaN
#
#                                                     desc  seller seats  power  \
# 23450  (* ABS elektronisch mit EBD, * Airbag: Beifahr...  Dealer     5  155.0
# 975    (Precio al contado: 78490 euros, IVA deducible...  Dealer     5  585.0
# 181    (Precio al contado: 20990 euros, CONTACTO LUIS...  Dealer     5  136.0
# 9101   (Advanced Grip control;Filet sécu. vertical d'...  Dealer     5  133.0
# 26271  (Precio al contado: 15200 euros, Ref.  6710KJS...  Dealer     5  120.0
# 3088   (OPEL GT 2.0L 264CV CABRIOLET, PREMIER PROPRIE...  Dealer     2  264.0
# 6570   (DEK:[6153005, Vettura Usata con chilometraggi...  Dealer     5  110.0
#
#        engine_size gears  CO2_emissions   manufacturer_colour drivetrain  \
# 23450        998.0     6           93.0  Chroma-Blau Metallic      Front
# 975         5461.0     7            NaN                   NaN        4WD
# 181         2143.0     7            NaN                   NaN      Front
# 9101        1199.0   NaN          156.0                 BLANC        NaN
# 26271       1969.0     6            NaN                Blanco      Front
# 3088        1998.0     5          218.0                   NaN       Rear
# 6570        1461.0     6          106.0                Bianco      Front
#
#       cylinders                                   fuel_consumption  \
# 23450         3                               4.1 l/100 km (comb.)
# 975           8  (11.9 l/100 km (comb.), 17.6 l/100 km (city), ...
# 181           4  (3.8 l/100 km (comb.), 4.6 l/100 km (city), 3....
# 9101        NaN                                                NaN
# 26271         4  (3.4 l/100 km (comb.), 3.7 l/100 km (city), 3....
# 3088          4  (9.2 l/100 km (comb.), 13 l/100 km (city), 6.9...
# 6570          4  (4.1 l/100 km (comb.), 4.9 l/100 km (city), 3....
#
#                                      comfort_convenience  \
# 23450  Air conditioning, Armrest, Automatic climate c...
# 975    Electrical side mirrors, Power windows, Rain s...
# 181    Air conditioning, Electrical side mirrors, Pow...
# 9101   Air conditioning, Armrest, Cruise control, Ele...
# 26271  Air conditioning, Automatic climate control, E...
# 3088   Air conditioning, Cruise control, Electrical s...
# 6570   Automatic climate control, 2 zones, Electrical...
#
#                                      entertainment_media  \
# 23450  Android Auto, Apple CarPlay, Bluetooth, CD pla...
# 975                                                  NaN
# 181                                                  NaN
# 9101            Digital radio, Hands-free equipment, USB
# 26271                                          Bluetooth
# 3088            CD player, MP3, On-board computer, Radio
# 6570   Bluetooth, CD player, MP3, On-board computer, ...
#
#                                          safety_security  \
# 23450  ABS, Adaptive headlights, Central door lock, C...
# 975    ABS, Central door lock, Driver-side airbag, Is...
# 181    ABS, Central door lock, Driver-side airbag, Is...
# 9101   ABS, Central door lock, Driver-side airbag, El...
# 26271  ABS, Central door lock, Driver-side airbag, El...
# 3088   ABS, Central door lock, Central door lock with...
# 6570   Central door lock, Driver-side airbag, Electro...
#
#                                                   extras  empty_weight  \
# 23450  Alloy wheels (16"), Automatically dimming inte...        1344.0
# 975                                          Sport seats        2350.0
# 181                                          Sport seats        1485.0
# 9101                                        Alloy wheels           NaN
# 26271                                       Alloy wheels        1423.0
# 3088                     Alloy wheels (18"), Sport seats        1438.0
# 6570                                                 NaN           NaN
#
#       model_code general_inspection last_service full_service_history  \
# 23450   8566/BUD                New          NaN                  Yes
# 975          NaN                NaN          NaN                  NaN
# 181          NaN                NaN          NaN                  NaN
# 9101         NaN                NaN          NaN                  NaN
# 26271        NaN                NaN          NaN                  NaN
# 3088         NaN                NaN          NaN                  Yes
# 6570         NaN                NaN          NaN                  NaN
#
#       non_smoker_vehicle emission_class emissions_sticker upholstery_colour  \
# 23450                Yes   Euro 6d-TEMP         4 (Green)             Black
# 975                  NaN            NaN               NaN               NaN
# 181                  NaN            NaN               NaN               NaN
# 9101                 NaN            NaN               NaN             Black
# 26271                NaN            NaN               NaN               NaN
# 3088                 Yes         Euro 4               NaN             Black
# 6570                 NaN         Euro 5               NaN               NaN
#
#          upholstery  production_date  previous_owner other_fuel_types  \
# 23450         Cloth              NaN               1      Electricity
# 975             NaN              NaN               0              NaN
# 181             NaN              NaN               0              NaN
# 9101            NaN              NaN               1              NaN
# 26271           NaN              NaN               0              NaN
# 3088   Full leather              NaN               1              NaN
# 6570         Velour           2015.0               2              NaN
#
#        power_consumption energy_efficiency_class  \
# 23450                NaN                      A+
# 975                  NaN                     NaN
# 181                  NaN                     NaN
# 9101                 NaN                     NaN
# 26271                NaN                     NaN
# 3088                 NaN                     NaN
# 6570                 NaN                     NaN
#
#                                           CO2_efficiency  \
# 23450  Calculated on basis of measured CO₂-emissions ...
# 975                                                  NaN
# 181                                                  NaN
# 9101                                                 NaN
# 26271                                                NaN
# 3088                                                 NaN
# 6570                                                 NaN
#
#        fuel_consumption_wltp CO2_emissions_wltp available_from  \
# 23450                    NaN                NaN            NaN
# 975                      NaN                NaN            NaN
# 181                      NaN                NaN            NaN
# 9101                     NaN                NaN            NaN
# 26271                    NaN                NaN            NaN
# 3088                     NaN                NaN            NaN
# 6570                     NaN                NaN            NaN
#
#       taxi_or_rental_car availability last_timing_belt_change  \
# 23450                NaN          NaN                     NaN
# 975                  NaN          NaN                     NaN
# 181                  NaN          NaN                     NaN
# 9101                 NaN          NaN                     NaN
# 26271                NaN          NaN                     NaN
# 3088                 NaN          NaN                     NaN
# 6570                 NaN          NaN                     NaN
#
#        electric_range_wltp  power_consumption_wltp battery_ownership   age  \
# 23450                  NaN                     NaN               NaN   1.0
# 975                    NaN                     NaN               NaN   5.0
# 181                    NaN                     NaN               NaN   5.0
# 9101                   NaN                     NaN               NaN   2.0
# 26271                  NaN                     NaN               NaN   4.0
# 3088                   NaN                     NaN               NaN  13.0
# 6570                   NaN                     NaN               NaN   7.0
#
#       fuel_type_new  energy_efficient  fuel_comb  fuel_city  fuel_country  \
# 23450        Petrol                 1        NaN        NaN           NaN
# 975          Petrol                 0       11.9       17.6          11.9
# 181          Diesel                 0        3.8        4.6           3.4
# 9101         Petrol                 0        NaN        NaN           NaN
# 26271        Diesel                 0        3.4        3.7           3.2
# 3088         Petrol                 0        9.2        NaN           6.9
# 6570         Diesel                 0        4.1        4.9           3.5
#
#        cc_num  em_num  ss_num  extras_num
# 23450    21.0    11.0    22.0         7.0
# 975       4.0     NaN     5.0         1.0
# 181       4.0     NaN     4.0         1.0
# 9101      9.0     3.0    12.0         1.0
# 26271     4.0     1.0     9.0         1.0
# 3088      7.0     4.0     9.0         2.0
# 6570      9.0     6.0    10.0         NaN

# %%
#ri16.to_csv('ri_cleaned.csv',index_label=True)

# %%
path_for_save ='ri_cleaned_z.csv'

# %%
ri16.to_csv(path_for_save,index_label=True)
